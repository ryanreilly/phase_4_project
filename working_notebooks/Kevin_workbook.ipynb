# %% [markdown]
# # Brands and Product Emotions
#
# **Authors:** Kevin McDonough, Brad Horn, Ryan Reilly

# %% [markdown]
# ## Overview
#
# This project analyzes data for over 9,000 tweets about product reviews for Apple and Google. Human raters rated the sentiment as positive, negative, or neither. The goal of this analysis is to build an NLP model that will accurately predict the sentiment of a tweet based on the tweets text. This will be done through exploratory data analysis and iterative predictive modeling using classification models.

# %% [markdown]
# ## Business Problem
#
# Apple and Google have hired us to predict the sentiment of tweets about theit products. They will use our analysis to gather critical feedback about problems in newly released products. Based on our analysis, we are going to provide reccomendations based on the following.
#
# - Which products to manage based on negative tweets
# - What people say most often about negative tweets
# -

# %% [markdown]
# ## Data Understanding
#
# Each row in this dataset represents a unique tweet made a by a user about an Apple or Google procduct. There are three columns in the dataset. Each feature and its description is listed below.

# %% [markdown]
# | Feature | Description|
# |:-------| :-------|
# |tweet_text| The full text of the tweet|
# |emotion_in_tweet_is_directed_at| The product the tweet is directed at|
# is_there_an_emotion_directed_at_a_brand_or_product| The sentiment label of the tweet in 4 classes (positive, negative, neutral, and I can't tell|

# %%
#For data engineering
import pandas as pd
import numpy as np
import re
import string

#For visualization
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

#To scale and one-hot encode our columns
from sklearn.preprocessing import LabelEncoder

#To build all of our models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelBinarizer

# nltk
import nltk
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.util import ngrams

#For Neural Net
from keras.utils.np_utils import to_categorical

#For counting words
import collections

#For Vectorizing
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

#Train test split, CV and Gridsearch
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

#To build our dummy model
from sklearn.dummy import DummyClassifier

#For evaluating our classification models
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report 
from sklearn.metrics import plot_roc_curve

#To apply oversampling for imbalanced dataset
from imblearn.over_sampling import SMOTE

#For building pipelines
from imblearn.pipeline import Pipeline as Pipeline

#to see how long a cell takes to run
import time

#Use the functions in the py file for preprocessing
import sys
#sys.path.insert(0, 'src/')
#import preprocessing

#To ignore warnings
import warnings
warnings.filterwarnings('ignore')

#Stopwords
stop_words = set(stopwords.words('english'))

# %%
#Import the data
df = pd.read_csv('../data/tweets.csv')

#Rename columns to get shorter clumn names
df.rename(columns={"tweet_text": "tweet",\
                   "emotion_in_tweet_is_directed_at":"product",\
                   "is_there_an_emotion_directed_at_a_brand_or_product": "sentiment"},\
          inplace=True)

# %%
#Take a look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8721 entries, 0 to 8720
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet      8720 non-null   object
#  1   product    3169 non-null   object
#  2   sentiment  8721 non-null   object
# dtypes: object(3)
# memory usage: 204.5+ KB

# %% [markdown]
# There looks to be nulls in the product column which we will have to deal with. We also may need to convert the tweet column to a string to be used for analysis.

# %%
#Take a look at the outcome variable and its value counts
df['sentiment'].value_counts().to_frame()
# Out:
#                                     sentiment
# No emotion toward brand or product       5156
# Positive emotion                         2869
# Negative emotion                          545
# I can't tell                              151

# %% [markdown]
# THere are 4 classes for our target variable. There looks to be a good balance of no emotion(neutral) and postive tweets but there are few negative tweets so we will need to implement a re-sampling technique in our models. For those tweets that are labeld as I can't tell, we will remove these rows from the dataset for our analysis and modeling.

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Handle Missing Values

# %%
#Create a dataframe with just those columns with NAs and there sums.
missing = pd.DataFrame(df.isna().sum(), columns = ['Nulls'])
#Label index column
missing.index.name = 'Feature'
#Just show the columns with missing data    
missing.sort_values(by=['Nulls'])
# Out:
#            Nulls
# Feature
# sentiment      0
# tweet          1
# product     5552

# %% [markdown]
# #### We will remove the row with no tweet.

# %%
df = df[df['tweet'].notna()]

# %% [markdown]
# #### Impute Product Column

# %%
# Need to figure out a way to impute values in this column if possible

# %% [markdown]
# ### Check for row duplicates and remove

# %%
print('Number of duplicates: {}'.format(len(df[df.duplicated()])))
# Out:
# Number of duplicates: 22

# %%
#Remove duplicates
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Remove rows where the label is "I cant tell"

# %%
#Remove tweets with "I can't tell" sentiment
df = df[df.sentiment != "I can't tell"]

# %% [markdown]
# ### Rename class lables

# %%
df['sentiment'].replace({'No emotion toward brand or product': 'Nuetral', 'Positive emotion': 'Positive', 'Negative emotion': 'Negative'}, inplace=True)

# %% [markdown]
# # Feature Engineering

# %%
df
# Out:
# Feature                                              tweet  \
# 0        .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1        @jessedee Know about @fludapp ? Awesome iPad/i...
# 2        @swonderlin Can not wait for #iPad 2 also. The...
# 3        @sxsw I hope this year's festival isn't as cra...
# 4        @sxtxstate great stuff on Fri #SXSW: Marissa M...
# ...                                                    ...
# 8716                         Ipad everywhere. #SXSW {link}
# 8717     Wave, buzz... RT @mention We interrupt your re...
# 8718     Google's Zeiger, a physician never reported po...
# 8719     Some Verizon iPhone customers complained their...
# 8720     �ϡ�����_��ʋ�΋�ҋ�������⋁_��������_���RT @mentio...
#
# Feature             product sentiment
# 0                    iPhone  Negative
# 1        iPad or iPhone App  Positive
# 2                      iPad  Positive
# 3        iPad or iPhone App  Negative
# 4                    Google  Positive
# ...                     ...       ...
# 8716                   iPad  Positive
# 8717                    NaN   Nuetral
# 8718                    NaN   Nuetral
# 8719                    NaN   Nuetral
# 8720                    NaN   Nuetral
#
# [8547 rows x 3 columns]

# %%
from textblob import TextBlob

# %%
#Create polarity function and subjectivity function
pol = lambda x: TextBlob(x).sentiment.polarity
pol(df['tweet'][1])

df['polarity'] = round(df['tweet'].apply(pol),2)

# %%
df
# Out:
# Feature                                              tweet  \
# 0        .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1        @jessedee Know about @fludapp ? Awesome iPad/i...
# 2        @swonderlin Can not wait for #iPad 2 also. The...
# 3        @sxsw I hope this year's festival isn't as cra...
# 4        @sxtxstate great stuff on Fri #SXSW: Marissa M...
# ...                                                    ...
# 8716                         Ipad everywhere. #SXSW {link}
# 8717     Wave, buzz... RT @mention We interrupt your re...
# 8718     Google's Zeiger, a physician never reported po...
# 8719     Some Verizon iPhone customers complained their...
# 8720     �ϡ�����_��ʋ�΋�ҋ�������⋁_��������_���RT @mentio...
#
# Feature             product sentiment  polarity
# 0                    iPhone  Negative     -0.25
# 1        iPad or iPhone App  Positive      0.47
# 2                      iPad  Positive     -0.16
# 3        iPad or iPhone App  Negative      0.00
# 4                    Google  Positive      0.80
# ...                     ...       ...       ...
# 8716                   iPad  Positive      0.00
# 8717                    NaN   Nuetral      0.00
# 8718                    NaN   Nuetral      0.00
# 8719                    NaN   Nuetral     -0.05
# 8720                    NaN   Nuetral      0.00
#
# [8547 rows x 4 columns]

# %% [markdown]
# # Preprocess for modeling

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kevinmcdonough/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['tweet'] = df['tweet'].astype(str)

# %%
def preprocess_tweet_text(tweet):
    # Lowercase
    tweet = tweet.lower()
    # Remove urls
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    # Remove user @ references and '#' from tweet
    tweet = re.sub(r'\@\w+|\#','', tweet)
    # Remove punctuations
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tweet_tokens = word_tokenize(tweet)
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    # Lemmatize
    lemmatizer = WordNetLemmatizer()
    lemma_words = [lemmatizer.lemmatize(w, pos='a') for w in filtered_words]
    #Return the words joined back together
    return " ".join(lemma_words)

# %%
df['tweet'] = df['tweet'].apply(preprocess_tweet_text)

# %%
df['tweet']
# Out:
# 0       3g iphone 3 hrs tweeting riseaustin dead need ...
# 1       know awesome ipadiphone app youll likely appre...
# 2                              wait ipad 2 also sale sxsw
# 3       hope years festival isnt crashy years iphone a...
# 4       great stuff fri sxsw marissa mayer google tim ...
#                               ...
# 8716                            ipad everywhere sxsw link
# 8717    wave buzz rt interrupt regularly scheduled sxs...
# 8718    googles zeiger physician never reported potent...
# 8719    verizon iphone customers complained time fell ...
# 8720    �ϡ�������ʋ�΋�ҋ�������⋁�����������rt google tes...
# Name: tweet, Length: 8547, dtype: object

# %%
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer_obj = Tokenizer(num_words=2000)

# %%
df['sentiment'].value_counts()
# Out:
# Nuetral     5142
# Positive    2861
# Negative     544
# Name: sentiment, dtype: int64

# %%
# Convert string labels to 0,1,2
le = LabelEncoder()
df['target'] = le.fit_transform(df['sentiment'])

# %%
# Separate features and labels 
X = df['tweet']
y = df['target']

# %%
# Create test and train datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state=1)

# %%
# Transform the product labels to numerical values
lb = LabelBinarizer()
lb.fit(y_train)

y_train_lb = to_categorical(lb.transform(y_train))[:, :, 1]
y_test_lb = to_categorical(lb.transform(y_test))[:, :, 1]

# %%
y_train_lb[0]
# Out:
# array([0., 0., 1.], dtype=float32)

# %%
X_train.values
# Out:
# array(['brilliant move apple even begins apple wins sxsw link',
#        'thats impressive quotpopupquot store must purchased ipad 2 enjoy sxsw',
#        'i7 releasing demons link codes valid 40075959p 031111 infektd sxsw zomb',
#        ...,
#        'cool team startups came via siliconvalley bus hacking apps exgoogle au stage w speakermeetup sxsw dogpatch labs',
#        'rt attending sxsw austin guide free download itunes link lp',
#        'iphone thirsty sxsw chevy volt lounge w 16 others link'],
#       dtype=object)

# %%
X_train = X_train.values
X_test = X_test.values

# %%
total_reviews = df['tweet'].values

# %%
total_reviews
# Out:
# array(['3g iphone 3 hrs tweeting riseaustin dead need upgrade plugin stations sxsw',
#        'know awesome ipadiphone app youll likely appreciate design also theyre giving free ts sxsw',
#        'wait ipad 2 also sale sxsw', ...,
#        'googles zeiger physician never reported potential ae yet fda relies physicians quotwere operating wout dataquot sxsw health2dev',
#        'verizon iphone customers complained time fell back hour weekend course new yorkers attended sxsw',
#        '�ϡ�������ʋ�\u038b�ҋ�������⋁�����������rt google tests ���checkin offers�\u06dd sxsw link'],
#       dtype=object)

# %%
tokenizer_obj.fit_on_texts(total_reviews)

# %%
max_length = max([len(s.split()) for s in total_reviews])

# %%
max_length
# Out:
# 26

# %%
vocab_size = len(tokenizer_obj.word_index) + 1

# %%
X_train_tokens = tokenizer_obj.texts_to_sequences(X_train)
X_test_tokens = tokenizer_obj.texts_to_sequences(X_test)

# %%
X_train_pad = pad_sequences(X_train_tokens, maxlen=max_length, padding='post')
X_test_pad = pad_sequences(X_test_tokens, maxlen=max_length, padding='post')

# %%
X_resampled, y_resampled = SMOTE().fit_resample(X_train_pad, y_train_lb)

# %%
len(y_resampled)
# Out:
# 9165

# %%
from keras.models import Sequential
from keras.layers import Embedding, Dense, LSTM, GRU, Flatten
from keras.layers.embeddings import Embedding

# %%
EMBEDDING_DIM = 100

# %%
print('Build model...')

model = Sequential()
model.add(Embedding(vocab_size, EMBEDDING_DIM, input_length=max_length))
model.add(GRU(units=32, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(3, activation='softmax'))
# Out:
# Build model...

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 26, 100)           1038200
# _________________________________________________________________
# gru (GRU)                    (None, 32)                12864
# _________________________________________________________________
# dense (Dense)                (None, 3)                 99
# =================================================================
# Total params: 1,051,163
# Trainable params: 1,051,163
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(X_test_pad)
# Out:
# 3419

# %%
model.fit(X_train_pad, y_train_lb, batch_size=128, epochs=12, validation_data=(X_test_pad, y_test_lb), verbose=1)
# Out:
# Epoch 1/12
# 41/41 [==============================] - 4s 91ms/step - loss: 0.5522 - acc: 0.5811 - val_loss: 0.5110 - val_acc: 0.6104
# Epoch 2/12
# 41/41 [==============================] - 3s 78ms/step - loss: 0.5204 - acc: 0.5957 - val_loss: 0.5092 - val_acc: 0.6104
# Epoch 3/12
# 41/41 [==============================] - 5s 134ms/step - loss: 0.5200 - acc: 0.5957 - val_loss: 0.5097 - val_acc: 0.6104
# Epoch 4/12
# 41/41 [==============================] - 4s 95ms/step - loss: 0.5202 - acc: 0.5957 - val_loss: 0.5085 - val_acc: 0.6104
# Epoch 5/12
# 41/41 [==============================] - 4s 99ms/step - loss: 0.5179 - acc: 0.5957 - val_loss: 0.5046 - val_acc: 0.6104
# Epoch 6/12
# 41/41 [==============================] - 5s 111ms/step - loss: 0.4991 - acc: 0.6004 - val_loss: 0.4794 - val_acc: 0.6309
# Epoch 7/12
# 41/41 [==============================] - 5s 118ms/step - loss: 0.4469 - acc: 0.6802 - val_loss: 0.4559 - val_acc: 0.6674
# Epoch 8/12
# 41/41 [==============================] - 4s 93ms/step - loss: 0.4028 - acc: 0.7270 - val_loss: 0.4627 - val_acc: 0.6718
# Epoch 9/12
# 41/41 [==============================] - 4s 108ms/step - loss: 0.3755 - acc: 0.7572 - val_loss: 0.4737 - val_acc: 0.6710
# Epoch 10/12
# 41/41 [==============================] - 4s 88ms/step - loss: 0.3575 - acc: 0.7713 - val_loss: 0.4887 - val_acc: 0.6689
# Epoch 11/12
# 41/41 [==============================] - 3s 85ms/step - loss: 0.3388 - acc: 0.7923 - val_loss: 0.5201 - val_acc: 0.6634
# Epoch 12/12
# 41/41 [==============================] - 4s 86ms/step - loss: 0.3262 - acc: 0.8038 - val_loss: 0.5292 - val_acc: 0.6677

# %% [markdown]
# ## Word2Vec

# %%
tweets = df['tweet'].values.tolist()
review_lines = list()

for tweet in tweets:
    # Lowercase
    tweet = tweet.lower()
    # Remove urls
    tweet = re.sub(r"http\S+|www\S+|https\S+", '', tweet, flags=re.MULTILINE)
    # Remove user @ references and '#' from tweet
    tweet = re.sub(r'\@\w+|\#','', tweet)
    # Remove punctuations
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    # Remove stopwords
    tweet_tokens = word_tokenize(tweet)
    filtered_words = [w for w in tweet_tokens if not w in stop_words]
    # Lemmatize
    lemmatizer = WordNetLemmatizer()
    lemma_words = [lemmatizer.lemmatize(w, pos='a') for w in filtered_words]
    #Return the words joined back together
    review_lines.append(lemma_words)

# %%
review_lines
# Out:
# [['3g',
#   'iphone',
#   '3',
#   'hrs',
#   'tweeting',
#   'riseaustin',
#   'dead',
#   'need',
#   'upgrade',
#   'plugin',
#   'stations',
#   'sxsw'],
#  ['know',
#   'awesome',
#   'ipadiphone',
#   'app',
#   'youll',
#   'likely',
#   'appreciate',
#   'design',
#   'also',
#   'theyre',
#   'giving',
#   'free',
#   'ts',
#   'sxsw'],
#  ['wait', 'ipad', '2', 'also', 'sale', 'sxsw'],
#  ['hope',
#   'years',
#   'festival',
#   'isnt',
#   'crashy',
#   'years',
#   'iphone',
#   'app',
#   'sxsw'],
#  ['great',
#   'stuff',
#   'fri',
#   'sxsw',
#   'marissa',
#   'mayer',
#   'google',
#   'tim',
#   'oreilly',
#   'tech',
#   'booksconferences',
#   'amp',
#   'matt',
#   'mullenweg',
#   'wordpress'],
#  ['new',
#   'ipad',
#   'apps',
#   'speechtherapy',
#   'communication',
#   'showcased',
#   'sxsw',
#   'conference',
#   'iear',
#   'edchat',
#   'asd'],
#  ['sxsw',
#   'starting',
#   'ctia',
#   'around',
#   'corner',
#   'googleio',
#   'hop',
#   'skip',
#   'jump',
#   'good',
#   'time',
#   'android',
#   'fan'],
#  ['beautifully',
#   'smart',
#   'simple',
#   'idea',
#   'rt',
#   'wrote',
#   'hollergram',
#   'ipad',
#   'app',
#   'sxsw'],
#  ['counting',
#   'days',
#   'sxsw',
#   'plus',
#   'strong',
#   'canadian',
#   'dollar',
#   'means',
#   'stock',
#   'apple',
#   'gear'],
#  ['excited',
#   'meet',
#   'sxsw',
#   'show',
#   'sprint',
#   'galaxy',
#   'still',
#   'running',
#   'android',
#   '21',
#   'fail'],
#  ['find',
#   'amp',
#   'start',
#   'impromptu',
#   'parties',
#   'sxsw',
#   'cant',
#   'wait',
#   'til',
#   'android',
#   'app',
#   'comes'],
#  ['foursquare',
#   'ups',
#   'game',
#   'time',
#   'sxsw',
#   'still',
#   'prefer',
#   'far',
#   'best',
#   'looking',
#   'android',
#   'app',
#   'date'],
#  ['got',
#   'ta',
#   'love',
#   'sxsw',
#   'google',
#   'calendar',
#   'featuring',
#   'top',
#   'parties',
#   'show',
#   'cases',
#   'check',
#   'rt',
#   'via',
#   'gt'],
#  ['great', 'sxsw', 'ipad', 'app'],
#  ['haha', 'awesomely', 'rad', 'ipad', 'app', 'hollergram', 'sxsw'],
#  ['holler', 'gram', 'ipad', 'itunes', 'app', 'store', 'via', 'sxsw'],
#  ['noticed',
#   'dst',
#   'coming',
#   'weekend',
#   'many',
#   'iphone',
#   'users',
#   'hour',
#   'late',
#   'sxsw',
#   'come',
#   'sunday',
#   'morning',
#   'sxsw',
#   'iphone'],
#  ['added',
#   'sxsw',
#   'flights',
#   'matching',
#   'people',
#   'planesairports',
#   'also',
#   'downloaded',
#   'iphone',
#   'app',
#   'nicely',
#   'done'],
#  ['must',
#   'sxsw',
#   'app',
#   'rt',
#   'lovely',
#   'review',
#   'forbes',
#   'sxsw',
#   'ipad',
#   'app',
#   'holler',
#   'gram'],
#  ['need',
#   'buy',
#   'ipad2',
#   'im',
#   'austin',
#   'sxsw',
#   'sure',
#   'ill',
#   'need',
#   'q',
#   'austin',
#   'apple',
#   'store'],
#  ['oh',
#   'god',
#   'sxsw',
#   'app',
#   'ipad',
#   'pure',
#   'unadulterated',
#   'awesome',
#   'easy',
#   'browse',
#   'events',
#   'ipad',
#   'website'],
#  ['okay', 'really', 'yay', 'new', 'android', 'app11', 'kthxbai', 'sxsw'],
#  ['photo', 'installed', 'sxsw', 'iphone', 'app', 'really', 'nice'],
#  ['really',
#   'enjoying',
#   'changes',
#   'gowalla',
#   '30',
#   'android',
#   'looking',
#   'forward',
#   'seeing',
#   'else',
#   'amp',
#   'foursquare',
#   'sleeves',
#   'sxsw'],
#  ['rt',
#   'im',
#   'looking',
#   'forward',
#   'smcdallas',
#   'pre',
#   'sxsw',
#   'party',
#   'wed',
#   'hoping',
#   'ill',
#   'win',
#   'ipad',
#   'resulting',
#   'shameless',
#   'promotion',
#   'chevysmc'],
#  ['rt',
#   'haha',
#   'awesomely',
#   'rad',
#   'ipad',
#   'app',
#   'hollergram',
#   'sxsw',
#   'via'],
#  ['someone',
#   'started',
#   'austin',
#   'group',
#   'google',
#   'groups',
#   'presxsw',
#   'great',
#   'idea'],
#  ['new',
#   '4sq3',
#   'looks',
#   'like',
#   'going',
#   'rock',
#   'update',
#   'iphone',
#   'android',
#   'push',
#   'tonight',
#   'sxsw',
#   'keepaustinweird'],
#  ['right', '3', 'app', 'android', 'sweeeeet', 'nice', 'job', 'team', 'sxsw'],
#  ['smart',
#   'hollergram',
#   'ipad',
#   'app',
#   'sxsw',
#   'may',
#   'leave',
#   'vuvuzela',
#   'home'],
#  ['must', 'app', 'ipad', 'going', 'sxsw', 'hollergram'],
#  ['attn',
#   'sxsw',
#   'frineds',
#   'register',
#   'gdgtlive',
#   'see',
#   'cobra',
#   'iradar',
#   'android',
#   'link'],
#  ['anyone', 'sxsw', 'want', 'sell', 'old', 'ipad'],
#  ['anyone', 'sxsw', 'bought', 'new', 'ipad', 'want', 'sell', 'old', 'ipad'],
#  ['sxsw',
#   'oooh',
#   'rt',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'possibly',
#   'today',
#   'link'],
#  ['best',
#   'rt',
#   'ha',
#   'first',
#   'line',
#   'ipad2',
#   'sxsw',
#   'quotpopupquot',
#   'apple',
#   'store',
#   'event',
#   'planner',
#   'eventprofs',
#   'pcma',
#   'engage365'],
#  ['spin',
#   'play',
#   'new',
#   'concept',
#   'music',
#   'discovery',
#   'ipad',
#   'amp',
#   'spincom',
#   'link',
#   'itunes',
#   'sxsw'],
#  ['false',
#   'alarm',
#   'google',
#   'circles',
#   'coming',
#   'now���and',
#   'probably',
#   'ever',
#   'link',
#   'google',
#   'circles',
#   'social',
#   'sxsw'],
#  ['vatornews',
#   'google',
#   'apple',
#   'force',
#   'print',
#   'media',
#   'evolve',
#   'link',
#   'sxsw'],
#  ['great',
#   'weather',
#   'greet',
#   'sxsw',
#   'still',
#   'need',
#   'sweater',
#   'nightapple',
#   'putting',
#   'quotflash',
#   'storequot',
#   'downtown',
#   'sell',
#   'ipad2'],
#  ['hootsuite',
#   'hootsuite',
#   'mobile',
#   'sxsw',
#   'updates',
#   'iphone',
#   'blackberry',
#   'amp',
#   'android',
#   'whether',
#   'you�۪re',
#   'getting',
#   'friend',
#   'link'],
#  ['hey',
#   'sxsw',
#   'long',
#   'think',
#   'takes',
#   'us',
#   'make',
#   'iphone',
#   'case',
#   'answer',
#   'using',
#   'zazzlesxsw',
#   'we�۪ll',
#   'make',
#   'one'],
#  ['mashable',
#   'ipad',
#   '2',
#   'takes',
#   'sxsw',
#   'video',
#   'ipad',
#   'sxsw',
#   'gadgets',
#   'link'],
#  ['ipad',
#   'rt',
#   'new',
#   'ubersocial',
#   'iphone',
#   'app',
#   'store',
#   'includes',
#   'uberguide',
#   'sxsw',
#   'sponsored',
#   'link'],
#  ['handheld',
#   '���hobo�۪',
#   'drafthouse',
#   'launches',
#   '���hobo',
#   'shotgun�۪',
#   'iphone',
#   'app',
#   'sxsw',
#   'link'],
#  ['hooray',
#   'rt',
#   '���',
#   'apple',
#   'opening',
#   'popup',
#   'store',
#   'austin',
#   'sxsw',
#   'link'],
#  ['orly',
#   '���',
#   'google',
#   'set',
#   'launch',
#   'new',
#   'social',
#   'network',
#   'circles',
#   'today',
#   'sxsw�\u06dd'],
#  ['wooooo',
#   '���',
#   'apple',
#   'store',
#   'downtown',
#   'austin',
#   'open',
#   'til',
#   'midnight',
#   'sxsw�\u06dd'],
#  ['khoi',
#   'vinh',
#   'says',
#   'conde',
#   'nasts',
#   'headlong',
#   'rush',
#   'ipad',
#   'publishing',
#   'quotfundamental',
#   'misunderstandingquot',
#   'platform',
#   'sxsw'],
#  ['���',
#   'link',
#   'lt',
#   'help',
#   'forward',
#   'doc',
#   'anonymous',
#   'accounts',
#   'techiesamp',
#   'ppl',
#   'help',
#   'us',
#   'jam',
#   'libya',
#   'sxsw'],
#  ['���',
#   '��',
#   'link',
#   '��',
#   'edchat',
#   'musedchat',
#   'sxsw',
#   'sxswi',
#   'classical',
#   'newtwitter'],
#  ['locationbased', 'fast', 'fun', 'future', 'link', 'via', 'sxsw'],
#  ['���',
#   'google',
#   'connect',
#   'digital',
#   'amp',
#   'physical',
#   'worlds',
#   'mobile',
#   'link',
#   'sxsw�\u06dd'],
#  ['���',
#   'talking',
#   'link',
#   'googles',
#   'effort',
#   'allow',
#   'users',
#   'open',
#   'systems',
#   'bettercloud',
#   'sxsw�\u06dd'],
#  ['link',
#   'rt',
#   'quotgoogle',
#   'tweetquot',
#   'new',
#   'quotthink',
#   'speakquot',
#   'mark',
#   'belinsky',
#   '911tweets',
#   'panel',
#   'sxsw'],
#  ['link',
#   'rt',
#   '1st',
#   'stop',
#   'sxsw',
#   'chaos',
#   'amp',
#   'hunt',
#   'austin',
#   'java',
#   'get',
#   'spy',
#   'game',
#   '4',
#   'chance',
#   '2',
#   'win',
#   'ipad'],
#  ['link', 'rt', 'sxsw', 'check', 'holler', 'gram', 'ipad', 'app', 'link'],
#  ['amp', 'fun', 'google', 'pic', 'sxsw', 'link'],
#  ['quotvia',
#   'link',
#   'guy',
#   'kawasaki',
#   'talks',
#   'enchanted',
#   'sxsw',
#   'knows',
#   'stuff',
#   'books',
#   'internet',
#   'apple',
#   'sxsw',
#   'quot'],
#  ['futuremf',
#   'link',
#   'spec',
#   'recipes',
#   'web',
#   'google',
#   'search',
#   'link',
#   'sxsw'],
#  ['smile',
#   'rt',
#   'think',
#   'apples',
#   'quotpopup',
#   'storequot',
#   'austin',
#   'would',
#   'lot',
#   'interesting',
#   'actually',
#   'know',
#   'popped',
#   'sxsw'],
#  ['rt', 'line', 'apple', 'store', 'insane', 'sxsw'],
#  ['agree',
#   'rt',
#   'wait',
#   'fiona',
#   'apple',
#   'town',
#   'somebody',
#   'kidnap',
#   'put',
#   'recording',
#   'studio',
#   'records',
#   'new',
#   'album',
#   'sxsw'],
#  ['sxsw',
#   'wan',
#   'na',
#   'buy',
#   'drink',
#   '7pm',
#   'fado',
#   '4th',
#   'link',
#   'join',
#   'us'],
#  ['attending', 'ipad', 'design', 'headaches', 'sxsw', 'link'],
#  ['boooo',
#   'rt',
#   'flipboard',
#   'developing',
#   'iphone',
#   'version',
#   'android',
#   'says',
#   'sxsw'],
#  ['check',
#   'amp',
#   'line',
#   'ipad',
#   '2',
#   'austin',
#   'power',
#   'sxswi',
#   'sxsw',
#   'link'],
#  ['check',
#   'rt',
#   'giving',
#   'added',
#   'value',
#   'location',
#   'based',
#   'services',
#   'needs',
#   'battle',
#   'checkin',
#   'fatigue',
#   'google',
#   'pnid',
#   'sxsw'],
#  ['chilcott',
#   'sxsw',
#   'stand',
#   'talking',
#   'blogger',
#   'staff',
#   'late',
#   'win',
#   'competition',
#   'best',
#   'tweet',
#   'mentioning',
#   'tshirt'],
#  ['rt',
#   'come',
#   'party',
#   'w',
#   'google',
#   'tonight',
#   'sxsw',
#   'link',
#   'bands',
#   'food',
#   'art',
#   'ice',
#   'cream',
#   'nifty',
#   'interactive',
#   'maps'],
#  ['gowallas',
#   'promises',
#   'launch',
#   'foursquare',
#   'checkin',
#   'groupon',
#   'rewardstype',
#   'service',
#   'sxsw',
#   'fingers',
#   'crossed',
#   'link'],
#  ['haha',
#   'rt',
#   'sxsw',
#   'news',
#   'yahoocom',
#   'loosing',
#   'search',
#   'traffic',
#   'new',
#   'site',
#   'googlecom',
#   'doubt',
#   'last',
#   'tho',
#   'w',
#   'weird',
#   'name'],
#  ['holla', 'rt', 'google', 'party', 'best', 'ever', 'get', 'butt', 'sxsw'],
#  ['love', 'iphone', 'case', 'sxsw', 'cant', 'get', 'phone', 'fail'],
#  ['worship', 'link', 'sxsw'],
#  ['ipad2',
#   'rt',
#   'droid',
#   'amp',
#   'mac',
#   'rt',
#   'agnerd',
#   'confession',
#   'using',
#   'laptop',
#   'ipad',
#   'amp',
#   'blackberry',
#   'follow',
#   'sxsw'],
#  ['launching',
#   'sxsw',
#   'rt',
#   'denies',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'debut',
#   'today',
#   'despite',
#   'report',
#   'link'],
#  ['new',
#   'post',
#   'iphone',
#   'app',
#   'makes',
#   'easy',
#   'connect',
#   'social',
#   'networks',
#   'people',
#   'meet',
#   'link',
#   'sxsw'],
#  ['nice',
#   'iphone',
#   'app',
#   'behaving',
#   'today',
#   'crashes',
#   'yesterday',
#   'ridiculous',
#   'sxsw'],
#  ['nice',
#   'rt',
#   'apple',
#   'opening',
#   'popup',
#   'store',
#   'ipad',
#   'launch',
#   'downtown',
#   'austin',
#   'sxsw',
#   'link',
#   'via'],
#  ['nice',
#   'rt',
#   'hey',
#   'apple',
#   'fans',
#   'get',
#   'peek',
#   'space',
#   'thats',
#   'slated',
#   'popup',
#   'sxsw',
#   'apple',
#   'store',
#   'tomorrow',
#   'link'],
#  ['one',
#   'thing',
#   'great',
#   'get',
#   'great',
#   'earth',
#   'face',
#   'google',
#   'company',
#   'love',
#   'sxsw',
#   'sxwsi'],
#  ['stay', 'tune', 'showcase', 'h4ckers', 'link', 'sxsw'],
#  ['thank', 'touchingstories', 'preso', 'sxsw', 'heres', 'deck', 'link'],
#  ['thank', 'awesome', 'sxsw', 'party', 'link'],
#  ['thanks',
#   'rt',
#   'youre',
#   'trying',
#   'contact',
#   'friends',
#   'family',
#   'japan',
#   'created',
#   'person',
#   'finder',
#   'link',
#   'sxsw'],
#  ['thanks',
#   'mention',
#   'new',
#   'speech',
#   'ipad',
#   'apps',
#   'showcased',
#   'sxsw',
#   'conf',
#   'link',
#   'sxswh',
#   'sxsh'],
#  ['thanks',
#   'publishing',
#   'news',
#   'new',
#   'medical',
#   'apps',
#   'sxswi',
#   'conf',
#   'blog',
#   'link',
#   'sxsw',
#   'sxswh',
#   'mhealth'],
#  ['sxsw',
#   'provide',
#   'iphone',
#   'chargers',
#   'ive',
#   'changed',
#   'mind',
#   'going',
#   'next',
#   'year'],
#  ['wonder', 'amp', 'apple', 'flashmob', 'tcrnchfcs45j', 'sxsw', 'ipad2'],
#  ['wonder', 'putting', 'tips', 'api', 'sxsw', 'suxsw'],
#  ['xmas',
#   'rt',
#   'shiny',
#   'new',
#   'apps',
#   'new',
#   'book',
#   'popup',
#   'ipad',
#   '2',
#   'stores',
#   'sxsw',
#   'christmas',
#   'nerds'],
#  ['yai',
#   'rt',
#   'new',
#   'ubersocial',
#   'iphone',
#   'app',
#   'store',
#   'includes',
#   'uberguide',
#   'sxsw',
#   'sponsored',
#   'cont',
#   'link'],
#  ['yes',
#   'rt',
#   'hey',
#   'ive',
#   'got',
#   'another',
#   'gem',
#   'gt',
#   'free',
#   'sxsw',
#   'link',
#   'sxsw'],
#  ['fast',
#   'fun',
#   'amp',
#   'future',
#   'google',
#   'presenting',
#   'sxsw',
#   'search',
#   'local',
#   'mobile'],
#  ['gsdampm',
#   'amp',
#   'googles',
#   'industry',
#   'party',
#   'tonight',
#   'see',
#   'u',
#   'link',
#   'sxsw',
#   'austin',
#   'welivehere',
#   'gsdm'],
#  ['new',
#   'buzz',
#   'quot',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'possibly',
#   'today',
#   'link',
#   'rt',
#   'sxswquot'],
#  ['headline',
#   'quotipad',
#   '2',
#   'musthave',
#   'gadget',
#   'sxswquot',
#   'hmm',
#   'could',
#   'seen',
#   'one',
#   'coming',
#   'link',
#   'gadget'],
#  ['know',
#   'quotdatavizquot',
#   'translates',
#   'quotsatanicquot',
#   'iphone',
#   'im',
#   'sayin',
#   'sxsw'],
#  ['quotgoogle',
#   'launched',
#   'checkins',
#   'month',
#   'agoquot',
#   'check',
#   'ins',
#   'ok',
#   'check',
#   'outs',
#   'future',
#   'sxsw',
#   'bizzy'],
#  ['quotgoogle',
#   'launched',
#   'checkins',
#   'month',
#   'agoquot',
#   'check',
#   'ins',
#   'ok',
#   'check',
#   'outs',
#   'future',
#   'sxsw',
#   'bizzy',
#   'via'],
#  ['���',
#   'quotgoogle',
#   'tweetquot',
#   'new',
#   'quotthink',
#   'speakquot',
#   'mark',
#   'belinsky',
#   '911tweets',
#   'panel',
#   'sxsw�\u06dd'],
#  ['attending',
#   'quotleft',
#   'brain',
#   'search',
#   'google',
#   'right',
#   'brain',
#   'search',
#   'xquot',
#   'bettersearch',
#   'talking',
#   'future',
#   'search',
#   'engines',
#   'sxsw'],
#  ['kawasaki',
#   'quotnot',
#   'cs',
#   'lewis',
#   'level',
#   'reasoning',
#   'apples',
#   'continued',
#   'existence',
#   'evidence',
#   'existence',
#   'godquot',
#   'bawling',
#   'sxsw'],
#  ['kawasaki',
#   'quotpagemaker',
#   'saved',
#   'applequot',
#   'oh',
#   'days',
#   'sxsw',
#   'jwtatl',
#   'enchantment'],
#  ['kawasaki',
#   'quotpagemaker',
#   'saved',
#   'applequot',
#   'oh',
#   'days',
#   'sxsw',
#   'jwtatl',
#   'enchantment',
#   'via'],
#  ['spark', 'android', 'teamandroid', 'award', 'sxsw', 'read', 'link'],
#  ['unboxing', 'apple', 'sxsw', 'apple', 'store', 'sxsw', 'link'],
#  ['sxsw',
#   'apple',
#   'ipad',
#   '2s',
#   'great',
#   'thoughts',
#   'w',
#   'japan',
#   'apac',
#   'regions',
#   'dealing',
#   'w',
#   'earthquake',
#   'amp',
#   'tsunami',
#   'trauma',
#   'sxswi'],
#  ['sxsw',
#   'apple',
#   'schools',
#   'marketing',
#   'experts',
#   'sxsw',
#   'cnet',
#   'blogs',
#   'link'],
#  ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'link'],
#  ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'link'],
#  ['temporary',
#   'apple',
#   'store',
#   'def',
#   'tent',
#   'powerhouse',
#   'gym',
#   'sxsw',
#   'link'],
#  ['temporary',
#   'apple',
#   'store',
#   '6th',
#   'congress',
#   'sxsw',
#   'along',
#   '10000',
#   'happy',
#   'hipsters'],
#  ['���',
#   'apple',
#   'wins',
#   'sxsw',
#   'link',
#   'opening',
#   'temporary',
#   'store',
#   'downtown',
#   'austin',
#   'support',
#   'ipad2',
#   'launch',
#   'good'],
#  ['headed', 'austin', 'sxsw', 'check', 'map', 'newbies', 'link', 'enjoy'],
#  ['funny',
#   'austin',
#   'trending',
#   'sxsw',
#   'matter',
#   'minutes',
#   'point',
#   'least',
#   'according',
#   'twitter',
#   'iphone'],
#  ['christian',
#   'ipad',
#   'iphone',
#   'devs',
#   'want',
#   'talk',
#   'u',
#   'sxsw',
#   'maybe',
#   'wk',
#   'together',
#   'cool',
#   'app'],
#  ['apple',
#   'ipad2',
#   'taken',
#   'sxsw',
#   'austin',
#   'storm',
#   'link',
#   'excited',
#   'part',
#   'mobile'],
#  ['haz', 'ipad2', 'ifrom', 'sxsw', 'gr8', 'link'],
#  ['stacks',
#   'ipad2s',
#   'waiting',
#   'bought',
#   'sxsw',
#   'got',
#   'mine',
#   'hassle',
#   'apple',
#   'handled',
#   'perfectly',
#   'link'],
#  ['googles',
#   'mobile',
#   'future',
#   'elusive',
#   'power',
#   'link',
#   'via',
#   'eurorscg',
#   'sxsw',
#   'sxswi'],
#  ['notatsxsw',
#   'sxsw',
#   'heres',
#   'link',
#   'free',
#   'download',
#   'meet',
#   'nearby',
#   'peps'],
#  ['smallbiz',
#   'need',
#   'reviews',
#   'play',
#   'google',
#   'placeswe',
#   'got',
#   'app',
#   'thatlink',
#   'seo',
#   'sxsw'],
#  ['smallbiz',
#   'need',
#   'reviews',
#   'play',
#   'google',
#   'placeswe',
#   'got',
#   'app',
#   'thatlink',
#   'seo',
#   'sxsw'],
#  ['samsung',
#   'sony',
#   'follow',
#   'apple',
#   'hp',
#   'lead',
#   'link',
#   'austin',
#   'atx',
#   'sxsw'],
#  ['samsung',
#   'sony',
#   'follow',
#   'apple',
#   'hp',
#   'lead',
#   'link',
#   'austin',
#   'atx',
#   'sxsw',
#   'via',
#   'rg'],
#  ['take',
#   'sxsw',
#   'rt',
#   'major',
#   'south',
#   'korean',
#   'director',
#   'gets',
#   '130000',
#   'make',
#   'movie',
#   'entirely',
#   'iphone',
#   'link'],
#  ['beautiful', 'sxsw', 'apple', 'store', 'sxsw', 'pic', 'link'],
#  ['q1',
#   'sxsw',
#   'sxswi',
#   'prep',
#   'amazing',
#   'pre',
#   'push',
#   'locally',
#   'focus',
#   'location',
#   'based',
#   'google',
#   'owns',
#   '10',
#   'regions',
#   'billboards',
#   'pr20chat'],
#  ['sxsw', 'accounts', 'need', 'follow', 'apps', 'download', 'iphone'],
#  ['headed',
#   'sxsw',
#   'want',
#   'sharegather',
#   'contact',
#   'info',
#   'link',
#   'turn',
#   'iphone',
#   'business',
#   'card',
#   'broadcaster'],
#  ['headed',
#   'sxsw',
#   'want',
#   'sharegather',
#   'contact',
#   'info',
#   'link',
#   'turn',
#   'iphone',
#   'link'],
#  ['btw',
#   'sxsw',
#   'apple',
#   'store',
#   'sold',
#   '3g',
#   'models',
#   'vzw',
#   'amp',
#   'atampt'],
#  ['must',
#   'sxsw',
#   'app',
#   'rt',
#   'lovely',
#   'review',
#   'forbes',
#   'sxsw',
#   'ipad',
#   'app',
#   'holler',
#   'gram',
#   'link'],
#  ['temporary', 'sxsw', 'apple', 'store', 'apple', 'sneaky', 'usual', 'link'],
#  ['anyone',
#   'sxsw',
#   'popup',
#   'apple',
#   'store',
#   'austin',
#   'thats',
#   'got',
#   'ta',
#   'hopping',
#   'place',
#   'today'],
#  ['���',
#   'sxsw',
#   'beta',
#   'testing',
#   'interactive',
#   'book',
#   'ipad',
#   'app',
#   'moonbot',
#   'studios',
#   'louisiana',
#   'cool',
#   'app�\u06dd'],
#  ['apple', 'sxsw', 'day', 'one', 'seeing', 'ton', 'ipad2'],
#  ['anyone',
#   'sxsw',
#   'chance',
#   'check',
#   'popup',
#   'apple',
#   'store',
#   'wondering',
#   'worth',
#   'trek',
#   'convention',
#   'center'],
#  ['���',
#   'sxsw',
#   'ipad',
#   'store',
#   'sold',
#   'everything',
#   'except',
#   '64gig',
#   'wifi',
#   'white�\u06dd',
#   'manage',
#   'get'],
#  ['���',
#   'sxsw',
#   'ipad',
#   'store',
#   'sold',
#   'everything',
#   'except',
#   '64gig',
#   'wifi',
#   'white�\u06dd',
#   'also',
#   'known',
#   'white',
#   'jeans',
#   'configuration'],
#  ['offered',
#   'sxsw',
#   'ipad',
#   'promo',
#   'ninjafinder',
#   'users',
#   'fans',
#   'sxsw',
#   'sucks',
#   'sxsw'],
#  ['sxsw',
#   'austin',
#   'conference',
#   'google',
#   'search',
#   'interactive',
#   'music',
#   'film'],
#  ['anyone', 'sxsw', 'know', 'apple', 'selling', 'ipad', '2'],
#  ['anyone',
#   'sxsw',
#   'know',
#   'apple',
#   'store',
#   'new',
#   'shipment',
#   'ipads',
#   'yet'],
#  ['marc',
#   'ecko',
#   'sxsw',
#   'launches',
#   'iphone',
#   'app',
#   'autodial',
#   'political',
#   'change',
#   'link',
#   'edreform',
#   'edtech',
#   'eduvc',
#   'fightthepaddle'],
#  ['sxsw',
#   'lonelyplanet',
#   'austin',
#   'guide',
#   'iphone',
#   'free',
#   'limited',
#   'time',
#   'link',
#   'lp',
#   'travel'],
#  ['free', 'sxsw', 'mp3', 'downloads', 'time', 'itunes', 'link'],
#  ['anyone',
#   'sxsw',
#   'heading',
#   'aclu',
#   'event',
#   'seen',
#   'owt',
#   'google',
#   'circles'],
#  ['sxsw',
#   'prompt',
#   'memory',
#   'go',
#   'google',
#   'map',
#   'describe',
#   'childhood',
#   'walk'],
#  ['apple', 'sxsw', 'store', 'still', 'ipad', '2s', 'short', 'lines'],
#  ['essential', 'sxsw', 'tools', 'link'],
#  ['left',
#   'sxsw',
#   'tradeshow',
#   'demo',
#   'google',
#   'theatre',
#   'ok',
#   'get',
#   'see',
#   'presenters',
#   'using'],
#  ['following',
#   'sxsw',
#   'tweets',
#   'google',
#   'realtime',
#   'four',
#   'platforms',
#   'tweet',
#   'deck',
#   'listening',
#   'panel',
#   'realizing',
#   'im',
#   'spoken',
#   'one',
#   'today'],
#  ['anyone',
#   'sxsw',
#   'want',
#   'ipad',
#   '2',
#   'im',
#   'line',
#   'pick',
#   'one',
#   'someone',
#   'willing',
#   'pay',
#   '50',
#   'grab',
#   '1'],
#  ['anyone',
#   'sxsw',
#   'want',
#   'make',
#   'quick',
#   'hundred',
#   'dollars',
#   'new',
#   'ipad2',
#   'ad',
#   'hoc',
#   'apple',
#   'store',
#   'gets',
#   'hundred',
#   'plus',
#   'cost'],
#  ['solving',
#   'sxswinduced',
#   'iphoneintoilet',
#   'crisis',
#   'apple',
#   'store',
#   'crisis'],
#  ['monday',
#   'sxsw',
#   'barry',
#   'diller',
#   'new',
#   'york',
#   'times',
#   'congress',
#   'lunch',
#   'w',
#   'hotel',
#   'party',
#   'google',
#   'party',
#   'six',
#   'dirty',
#   'martinis',
#   'mondays'],
#  ['attending',
#   'sxsw',
#   'austin',
#   'guide',
#   'free',
#   'download',
#   'itunes',
#   'link',
#   'lp'],
#  ['seriously',
#   'sxsw',
#   'testing',
#   'mobile',
#   'apps',
#   'constant',
#   'ipad',
#   'crashes',
#   'causing',
#   'lost',
#   'schedules',
#   'sync',
#   'wp7'],
#  ['ready',
#   'sxsw',
#   'iphone',
#   'apps',
#   '2',
#   'make',
#   'ur',
#   'blogging',
#   'easy',
#   'link',
#   'sxsw',
#   'sxswi'],
#  ['ipad2', 'sxswa', 'conflagration', 'doofusness', 'link'],
#  ['attention',
#   'sxswers',
#   'link',
#   'rumored',
#   'popup',
#   'temporary',
#   'apple',
#   'store',
#   'sxsw',
#   'ipad',
#   '2',
#   'launch',
#   'needs'],
#  ['went', 'sxswi', 'lousy', 'ipad', 'sxsw', 'link'],
#  ['hey',
#   'sxsw',
#   'sxswi',
#   'folks',
#   'want',
#   'learn',
#   'security',
#   'come',
#   'bsidesaustin',
#   'link'],
#  ['attending',
#   'sxswi',
#   'work',
#   'iphone',
#   'ipad',
#   'game',
#   'development',
#   'looking',
#   'hire',
#   'austinbased',
#   'ios',
#   'developer',
#   'im',
#   'man',
#   'lets',
#   'talk',
#   'sxsw'],
#  ['winning', 'picture', 'android', 'google', 'sxsw', 'link'],
#  ['gsdampm',
#   'google',
#   '710',
#   'rt',
#   'whats',
#   'best',
#   'party',
#   'hit',
#   'tonight',
#   'sxsw'],
#  ['gsdampm', 'google', 'industry', 'party', 'sxsw', 'great', 'meet', 'link'],
#  ['spent',
#   '1000',
#   'come',
#   'sxsw',
#   'youve',
#   'already',
#   'used',
#   'ipad',
#   '1',
#   'wait',
#   'couple',
#   'city',
#   'blocks',
#   'ipad2',
#   'sxsw',
#   'link'],
#  ['behind',
#   '100s',
#   'emails',
#   'give',
#   '1',
#   'line',
#   'iphone',
#   'composed',
#   'replies',
#   'sxsw',
#   'protip'],
#  ['like',
#   '10pm',
#   'night',
#   'line',
#   'around',
#   'block',
#   'popup',
#   'apple',
#   'stores',
#   'selling',
#   'ipad2s',
#   'sxsw'],
#  ['1154', 'free', 'songs', 'sxsw', 'year', 'alone', 'link'],
#  ['150', 'million', 'mobile', 'users', 'google', 'maps', 'mobile', 'sxsw'],
#  ['currently',
#   '150',
#   'people',
#   'line',
#   'quotpop',
#   'apple',
#   'storequot',
#   'sxsw'],
#  ['ipad',
#   '2',
#   'available',
#   'sxsw',
#   '64gb',
#   'wifionly',
#   'model',
#   '699',
#   'plus',
#   'optional',
#   'leather',
#   'smart',
#   'cover',
#   '69'],
#  ['���',
#   'love',
#   '2',
#   'entertain',
#   'you��please',
#   'don�۪t',
#   'grateful',
#   '��',
#   'link',
#   '��',
#   'edchat',
#   'musedchat',
#   'sxsw',
#   'sxswi',
#   'classical',
#   'newtwitter'],
#  ['less',
#   '2',
#   'hours',
#   'announce',
#   'details',
#   'ipad',
#   '2',
#   'giveaway',
#   'sxsw',
#   'sxswi'],
#  ['im',
#   '2',
#   'ipad',
#   '2s',
#   'seen',
#   'wild',
#   'people',
#   'say',
#   'fast',
#   'still',
#   'pics',
#   'terrible',
#   'sxsw'],
#  ['ipad', '2', 'queue', 'sxsw', 'course'],
#  ['ipad', '2', 'takes', 'sxsw', 'video', 'link'],
#  ['many', 'ipad', '2s', 'snapping', 'away', 'keynote', 'slides', 'sxsw'],
#  ['apple',
#   '200m',
#   'users',
#   'credit',
#   'cards',
#   'syncd',
#   'itunes',
#   'one',
#   'click',
#   'purchase',
#   'winning',
#   'sxsw'],
#  ['2nd',
#   'cocktail',
#   'quottexas',
#   'snowflakequot',
#   'google',
#   'cnngrill',
#   'sxsw'],
#  ['new',
#   'post',
#   '3',
#   'iphone',
#   'apps',
#   'well',
#   'using',
#   'south',
#   'southwest',
#   'interactive',
#   'link',
#   'sxsw',
#   'sxswi'],
#  ['new',
#   'post',
#   '3',
#   'iphone',
#   'apps',
#   'well',
#   'using',
#   'south',
#   'southwest',
#   'interactive',
#   'sxsw',
#   'sxswi',
#   'link'],
#  ['sweet', 'new', '3d', 'google', 'maps', 'demo', 'going', 'ballroom', 'sxsw'],
#  ['35',
#   'million',
#   'miles',
#   'per',
#   'day',
#   'driving',
#   'google',
#   'maps',
#   'navigation',
#   'sxsw'],
#  ['rt',
#   '4',
#   'pm',
#   'ipad2',
#   'line',
#   'apple',
#   'store',
#   'long',
#   'wide',
#   '���',
#   '250',
#   'people',
#   'one',
#   'hour',
#   'sxsw'],
#  ['u',
#   'smart',
#   '4',
#   'packing',
#   'extra',
#   'rt',
#   'way',
#   'sunny',
#   'austin',
#   'sxsw',
#   'extra',
#   'iphone',
#   'stow',
#   'case'],
#  ['wonder',
#   '4sqwill',
#   'attempt',
#   'block',
#   'gowalla',
#   'crosscheckins',
#   'way',
#   'facebook',
#   'blocked',
#   'googles',
#   'contacts',
#   'connections',
#   'sxsw',
#   'lbswars'],
#  ['check',
#   '5',
#   'steps',
#   'bulletproof',
#   'ux',
#   'strategy',
#   'sxsw',
#   'link',
#   'sxsw',
#   'rhjrux5',
#   'link'],
#  ['wandering',
#   '6th',
#   'street',
#   'girls',
#   'stopped',
#   'ceviche',
#   'mojitos',
#   'apple',
#   'juice',
#   'amp',
#   'ice',
#   'cream',
#   'sxsw'],
#  ['youre',
#   'band',
#   'sxsw',
#   'want',
#   'share',
#   'track',
#   'audience',
#   'stage',
#   'use',
#   'frostwire',
#   'android',
#   'theres',
#   'wifi',
#   'available'],
#  ['weve',
#   'got',
#   'busy',
#   'week',
#   'ahead',
#   'new',
#   'book',
#   'google',
#   'apps',
#   'available',
#   'amazon',
#   'amp',
#   'attending',
#   'sxsw'],
#  ['believe',
#   'went',
#   'aussies',
#   'sxsw',
#   'rt',
#   'ipad',
#   '2',
#   'sold',
#   '70',
#   'went',
#   'new',
#   'buyers',
#   'report',
#   'link'],
#  ['���',
#   'google',
#   'spreadsheet',
#   '270',
#   'parties',
#   'sxsw',
#   'year',
#   'oo',
#   'link',
#   'plan',
#   'going',
#   'sxsw',
#   'party'],
#  ['guy',
#   'line',
#   'apples',
#   'popup',
#   'store',
#   'sixth',
#   'street',
#   'austin',
#   'quotim',
#   'guyquot',
#   'told',
#   'sxsw'],
#  ['u',
#   'iphone',
#   'dont',
#   'need',
#   'caruse',
#   'zimride',
#   'etc',
#   'share',
#   'rides',
#   'sxsw',
#   'shareable'],
#  ['ive', 'seen', 'lot', 'tablets', 'every', 'single', 'one', 'ipad', 'sxsw'],
#  ['receiving',
#   'lot',
#   'messages',
#   'telling',
#   'im',
#   'sexy',
#   'response',
#   'post',
#   'looking',
#   'meet',
#   'fellow',
#   'christian',
#   'iphone',
#   'devs',
#   'sxsw'],
#  ['picked',
#   'mophie',
#   'battery',
#   'case',
#   '4',
#   'iphone',
#   'prep',
#   'sxsw',
#   'lugging',
#   'around',
#   'laptop',
#   'amp',
#   'using',
#   'phone',
#   'huge',
#   'win',
#   'last',
#   'year'],
#  ['thats',
#   'news',
#   'p',
#   'rt',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'possibly',
#   'today',
#   'link',
#   'sxsw'],
#  ['took',
#   'piss',
#   'trade',
#   'show',
#   'ipad',
#   'one',
#   'hand',
#   'iphone',
#   'pissing',
#   'kiiiiiilling',
#   'right',
#   'sxsw'],
#  ['rumor',
#   'monger',
#   'good',
#   'read',
#   '�',
#   'google',
#   'circles',
#   'preview',
#   'sxsw',
#   'link',
#   'via',
#   'socbiz',
#   'fb'],
#  ['hobo', 'shotgun', 'iphone', 'game', 'link', 'sxsw'],
#  ['hobo',
#   'shotgun',
#   'video',
#   'game',
#   'coming',
#   'ipadiphone',
#   'users',
#   'yes',
#   'please',
#   'link',
#   'sxsw'],
#  ['build',
#   'store',
#   'less',
#   '24',
#   'hours',
#   'one',
#   'big',
#   'launches',
#   'companys',
#   'history',
#   'got',
#   'apple',
#   'sxsw',
#   'ipad2'],
#  ['took',
#   'survey',
#   'iphone',
#   'starbucks',
#   'line',
#   'got',
#   'free',
#   'starbucks',
#   'gift',
#   'card',
#   'instant',
#   'research',
#   'instant',
#   'gratification',
#   'sxsw',
#   'gsdm'],
#  ['apple',
#   'temporary',
#   'retail',
#   'store',
#   'austin',
#   'ipad',
#   '2',
#   'release',
#   'today',
#   'opens',
#   '5pm',
#   'sxsw',
#   'sxswi',
#   'ipad2'],
#  ['read',
#   'groupme',
#   'sxswsounds',
#   'like',
#   'incredible',
#   'app',
#   'available',
#   'android',
#   'phones',
#   'yet'],
#  ['wondering',
#   'circles',
#   'gt',
#   'google',
#   'reveal',
#   'new',
#   'social',
#   'network',
#   'sxsw',
#   'link'],
#  ['google', 'search', 'local', 'marissa', 'mayer', 'sxsw'],
#  ['wondering',
#   'street',
#   'closures',
#   'sxsw',
#   'made',
#   'google',
#   'map',
#   'show',
#   'link',
#   'sxsw',
#   'austin'],
#  ['google',
#   'another',
#   'go',
#   'social',
#   'quotgoogle',
#   'circlesquot',
#   'sxsw',
#   'google'],
#  ['questions', 'whats', 'inside', 'ipad', '2', 'fire', 'way', 'sxsw'],
#  ['paraormal',
#   'activity',
#   'sanctuary',
#   'iphone',
#   'game',
#   'sketching',
#   'ar',
#   'experience',
#   'interactivity',
#   'quotmagic',
#   'lensequot',
#   'eduar',
#   'sxsw'],
#  ['apple',
#   'iie',
#   'ad',
#   '85',
#   'si',
#   'swimsuit',
#   'issue',
#   'garage',
#   'sale',
#   'sxsw',
#   'link'],
#  ['flipboard',
#   'adds',
#   'instagram',
#   'photos',
#   'social',
#   'search',
#   'apps',
#   'link',
#   'apple',
#   'socialsearch',
#   'sxsw'],
#  ['spent',
#   'aftrnoon',
#   'frozen',
#   'lake',
#   'photographing',
#   'brother',
#   'scott',
#   'amp',
#   'team',
#   'catch',
#   'sxsw',
#   'ths',
#   'weeknd',
#   'link'],
#  ['iphone',
#   'alarms',
#   'botch',
#   'timechange',
#   'many',
#   'sxswers',
#   'freak',
#   'late',
#   'flights',
#   'missed',
#   'panels',
#   'behind',
#   'bloody',
#   'marys'],
#  ['shouts',
#   'ladies',
#   'holding',
#   'ipad',
#   '2s',
#   'free',
#   'sxsw',
#   'shows',
#   'take',
#   'photos',
#   'sipping',
#   'free',
#   'beer',
#   'cc'],
#  ['dj',
#   'hoodie',
#   'allen',
#   'due',
#   'respect',
#   'probably',
#   'make',
#   'way',
#   'back',
#   'google',
#   'sxsw'],
#  ['meant', 'also', 'wish', 'sxsw', 'dyac', 'stupid', 'iphone'],
#  ['audioboo',
#   'american',
#   'dream',
#   'bust',
#   'link',
#   'ipad',
#   'sxsw',
#   'bum',
#   'begger',
#   'us',
#   'socialart',
#   'documentally'],
#  ['skifta',
#   'appbased',
#   'media',
#   'shifting',
#   'service',
#   'turns',
#   'android',
#   'phone',
#   'sxsw',
#   'mashable',
#   'sxswi',
#   'link'],
#  ['rumors',
#   'apple',
#   'store',
#   'opening',
#   'sxsw',
#   '6th',
#   'amp',
#   'congress',
#   'signs',
#   'point',
#   'yes',
#   'link'],
#  ['apple', 'security', 'guy', 'locks', 'store', 'sxsw', 'link'],
#  ['apple',
#   'security',
#   'guy',
#   'locks',
#   'store',
#   'sxsw',
#   'realtime',
#   'sxsw',
#   'link',
#   'curated'],
#  ['got', 'ipad', '2', 'sxsw', 'link', 'cc'],
#  ['picked',
#   'ipad',
#   '2',
#   'sxsw',
#   'pop',
#   'apple',
#   'store',
#   '15',
#   'minute',
#   'wait'],
#  ['brilliant',
#   'enlightening',
#   'game',
#   'mechanics',
#   'presentation',
#   'google',
#   'sxsw'],
#  ['gsdampm', 'googlesitting', 'tree', 'link', 'sxsw', 'gsdm'],
#  ['heres',
#   'pic',
#   'winning',
#   'ipad',
#   'unsix',
#   'sxsw',
#   'cc',
#   'link',
#   'cont',
#   'link'],
#  ['iphone',
#   'thirsty',
#   'sxsw',
#   'chevy',
#   'volt',
#   'lounge',
#   'w',
#   '16',
#   'others',
#   'link'],
#  ['iphone',
#   'thirsty',
#   'sxsw',
#   'chevy',
#   'volt',
#   'lounge',
#   'w',
#   '16',
#   'others',
#   'link',
#   'link'],
#  ['came',
#   'left',
#   'sxsw',
#   'iphone',
#   'playing',
#   'song',
#   'chosen',
#   'random',
#   'skreams',
#   'listening',
#   'records',
#   'wall',
#   'appropriate'],
#  ['marketing', 'sales', 'genius', 'link', 'apple', 'sxsw'],
#  ['arduino',
#   'android',
#   'flaming',
#   'skulls',
#   'link',
#   'refrigerator',
#   'speaks',
#   'salon',
#   'k',
#   '330pm',
#   'sxsw',
#   'smartthings'],
#  ['reminder',
#   'android',
#   'chrome',
#   'tts',
#   'talk',
#   '1',
#   'pm',
#   'today',
#   'link',
#   'sxsw'],
#  ['ipad',
#   '2',
#   'vs',
#   'android',
#   'vs',
#   'world',
#   'panel',
#   'sxsw',
#   'today',
#   '330pm',
#   'link'],
#  ['backupify',
#   'announces',
#   'cloudsight',
#   'search',
#   'first',
#   'searchable',
#   'archive',
#   'solution',
#   'social',
#   'media',
#   'google',
#   'apps',
#   'sxsw',
#   'sxswi',
#   'link'],
#  ['google',
#   'announcing',
#   'social',
#   'network',
#   'quotcirclesquot',
#   'via',
#   'sxsw',
#   'tweets',
#   'interesting',
#   'myopia',
#   'cause',
#   'buzz',
#   'jokes',
#   'interesting'],
#  ['need',
#   'sxsw',
#   'ipad',
#   'iphone',
#   'laptop',
#   'dictaphone',
#   'vidcamera',
#   'wow',
#   'love',
#   'meet',
#   'real',
#   'cerebellum',
#   'charged',
#   'people'],
#  ['u', 'see', 'anything', 'googles', 'circles', 'sxsw'],
#  ['sxsw',
#   'app',
#   'iphone',
#   'ridiculous',
#   'personal',
#   'planner',
#   'next',
#   '5',
#   'days'],
#  ['sxsw', 'app', 'android', 'huge', 'props', 'amp', 'get', 'link'],
#  ['found',
#   'app',
#   'kyping',
#   'iphones',
#   'geolocation',
#   'amp',
#   'releasing',
#   'background',
#   'need',
#   'patch',
#   'batterykiller',
#   'sxsw'],
#  ['sxsw',
#   'app',
#   'iphone',
#   'live',
#   'rsvp',
#   'events',
#   'phone',
#   'amp',
#   'check',
#   'sundayswaggereventbritecom',
#   '320',
#   'scoremore'],
#  ['iphone', 'app', 'screen', 'sxsw', 'missing', 'link'],
#  ['love',
#   'app',
#   'awesome',
#   'rt',
#   'must',
#   'see',
#   'android',
#   'app',
#   'sxsw',
#   'quotbizzyquot',
#   'link'],
#  ['sxsw',
#   'apple',
#   'quotpopupquot',
#   'store',
#   'nuts',
#   'still',
#   'packed',
#   '1130',
#   'link'],
#  ['say', 'apple', 'sxsw', 'popup', 'store', 'austin', 'link'],
#  ['breaking',
#   'apple',
#   'announces',
#   'partnership',
#   'wporn',
#   'industry',
#   'new',
#   'ipad2',
#   'video',
#   'chat',
#   'app',
#   'called',
#   'quotofacetimequot',
#   'sxsw'],
#  ['course',
#   'apple',
#   'built',
#   'temp',
#   'store',
#   'austin',
#   'texas',
#   'understand',
#   'concept',
#   'corralling',
#   'cattle',
#   'sxsw',
#   'pickmeupanipad2'],
#  ['love',
#   'apple',
#   'didnt',
#   'let',
#   'something',
#   'like',
#   'retail',
#   'store',
#   'near',
#   'sxsw',
#   'keep',
#   'away',
#   'opening',
#   'popup',
#   'store',
#   'link'],
#  ['surprise',
#   'apple',
#   'opened',
#   'popup',
#   'store',
#   'austin',
#   'nerds',
#   'town',
#   'sxsw',
#   'get',
#   'new',
#   'link',
#   'cnet'],
#  ['surprise',
#   'apple',
#   'opened',
#   'popup',
#   'store',
#   'austin',
#   'nerds',
#   'town',
#   'sxsw',
#   'get',
#   'new',
#   'ipads',
#   'link',
#   'cnet'],
#  ['surprise',
#   'apple',
#   'opened',
#   'popup',
#   'store',
#   'austin',
#   'nerds',
#   'town',
#   'sxsw',
#   'get',
#   'new',
#   'ipads',
#   'link'],
#  ['surprise',
#   'apple',
#   'opened',
#   'popup',
#   'store',
#   'austin',
#   'nerds',
#   'town',
#   'sxsw',
#   'get',
#   'new',
#   'ipads',
#   'link'],
#  ['technews',
#   'apple',
#   'heads',
#   'sxsw',
#   'sets',
#   'temporary',
#   'store',
#   'austin',
#   'link',
#   'technews',
#   'apple',
#   'ipad2',
#   'rancewilemon',
#   'sxsw',
#   'tech'],
#  ['���',
#   'apple',
#   'great',
#   'example',
#   'retail',
#   'store',
#   'layed',
#   'future',
#   'registers',
#   'checkout',
#   'line',
#   'sxsw'],
#  ['���',
#   'apple',
#   'opening',
#   'temporary',
#   'store',
#   'downtown',
#   'austin',
#   'sxsw',
#   'ipad',
#   '2',
#   'launch',
#   'link',
#   'gswsxsw'],
#  ['���',
#   'apple',
#   'opening',
#   'temporary',
#   'store',
#   'downtown',
#   'austin',
#   'sxsw',
#   'ipad',
#   '2',
#   'launchquot',
#   'oh',
#   'yay',
#   'traffic'],
#  ['sxsw',
#   'apple',
#   'popup',
#   'store',
#   'open',
#   'noon',
#   'fresh',
#   'shipment',
#   'ipad',
#   '2s',
#   'im',
#   'pretty',
#   'sure',
#   'im',
#   'going',
#   'get',
#   'one',
#   'fingers',
#   'crossed'],
#  ['technews',
#   'apple',
#   'saves',
#   'sxsw',
#   'set',
#   'open',
#   'popup',
#   'store',
#   'link',
#   'technews',
#   'apple',
#   'sxsw',
#   'tech'],
#  ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'link'],
#  ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'link'],
#  ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'link', 'via'],
#  ['sxsw',
#   'apple',
#   'schools',
#   'marketing',
#   'experts',
#   'link',
#   'via',
#   'ltlt',
#   'true',
#   'love',
#   'loathe',
#   'one',
#   'marketing',
#   'like'],
#  ['sxsw', 'apple', 'schools', 'marketing', 'experts', 'cnet', 'link'],
#  ['sxsw',
#   'apple',
#   'schools',
#   'marketing',
#   'experts',
#   'cnet',
#   'blogs',
#   'link',
#   'austin',
#   'atx',
#   'retail'],
#  ['���',
#   'apple',
#   'store',
#   'downtown',
#   'austin',
#   'open',
#   'til',
#   'midnight',
#   'sxsw�\u06dd',
#   'theres',
#   'still',
#   'time'],
#  ['���',
#   'apple',
#   'store',
#   'downtown',
#   'austin',
#   'open',
#   'til',
#   'midnight',
#   'sxsw�\u06dd',
#   'ipad2',
#   'left',
#   'stock'],
#  ['apple', 'store', 'congress', 'link', 'sxsw', 'austin'],
#  ['quotthe',
#   'apple',
#   'store',
#   'mall',
#   'sunday',
#   '10x',
#   'crowded',
#   'line',
#   'fake',
#   'need',
#   'fucking',
#   'donglequot',
#   'genius',
#   'let',
#   'sxsw'],
#  ['2wks', 'apple', 'store', '6th', 'austin', 'street', 'opened', 'sxsw'],
#  ['special',
#   'apple',
#   'store',
#   'opening',
#   '6th',
#   'congress',
#   'sxsw',
#   'amp',
#   'ipad',
#   '2',
#   'launch',
#   'apple',
#   'ipad2',
#   'sxsw',
#   'fb'],
#  ['makeshift',
#   'apple',
#   'store',
#   '6th',
#   'congress',
#   'youre',
#   'kidding',
#   'amazing',
#   'sxsw',
#   'apple'],
#  ['temporary', 'apple', 'store', 'sxsw', 'huge', 'line', 'link'],
#  ['temporary',
#   'apple',
#   'store',
#   'sxsw',
#   'really',
#   'coolas',
#   'ipad',
#   '2',
#   'apple',
#   'sxsw',
#   'fanboy'],
#  ['temporary',
#   'apple',
#   'store',
#   'set',
#   'sxsw',
#   'shit',
#   'temptation',
#   'going',
#   'control'],
#  ['temporary',
#   'apple',
#   'store',
#   'sxsw',
#   'line',
#   'goes',
#   'around',
#   'block',
#   'link'],
#  ['temporary',
#   'apple',
#   'store',
#   'opens',
#   '6th',
#   'amp',
#   'congress',
#   'tomorrow',
#   'ipad2',
#   'sxsw'],
#  ['temporary',
#   'apple',
#   'store',
#   'opens',
#   '5pm',
#   '6th',
#   'congress',
#   'line',
#   'already',
#   'growing',
#   'ipad',
#   'viewio',
#   'link',
#   'via',
#   'sxsw'],
#  ['temporary',
#   'apple',
#   'store',
#   'block',
#   'office',
#   'cant',
#   'wait',
#   'see',
#   'line',
#   'tomorrow',
#   'photos',
#   'come',
#   'sxsw',
#   'ipad2'],
#  ['sxsw',
#   'apple',
#   'store',
#   'opens',
#   'noon',
#   'day',
#   'closes',
#   'run',
#   'ipad2s',
#   'didnt',
#   'buy',
#   'stock',
#   '10',
#   'years',
#   'ago'],
#  ['base', 'camp', 'apple', 'sxsw', 'link'],
#  ['ipad', 'news', 'apps', 'last', 'year', 'sxsw', 'link'],
#  ['10',
#   'iphone',
#   'apps',
#   'you�۪ll',
#   'probably',
#   'need',
#   'use',
#   'sxsw',
#   'link'],
#  ['150', 'million', 'mobile', 'google', 'maps', 'users', 'sxsw'],
#  ['lines',
#   'already',
#   'forming',
#   'apples',
#   'popup',
#   'store',
#   'austin',
#   'arent',
#   'people',
#   'see',
#   'festival',
#   'link',
#   'sxsw'],
#  ['android',
#   'rt',
#   '10',
#   'new',
#   'mobile',
#   'apps',
#   'i�۪ll',
#   'using',
#   'at��sxsw',
#   'link'],
#  ['sxsw',
#   'attending',
#   'sxsw',
#   'report',
#   'see',
#   'android',
#   'phone',
#   'get',
#   'bannka',
#   'app'],
#  ['ipad',
#   'apps',
#   'like',
#   'software',
#   'development',
#   'release',
#   'start',
#   'working',
#   'update',
#   'sxsw'],
#  ['tweets',
#   'stalled',
#   'data',
#   'sluggish',
#   'come',
#   'atampt',
#   'verizon',
#   'embarrassing',
#   'iphone',
#   'customers',
#   'havent',
#   'switched',
#   'sxsw',
#   'iphone'],
#  ['tweeting',
#   'google',
#   'coming',
#   'circles',
#   'platform',
#   'today',
#   'outside',
#   'circle',
#   'keep',
#   'itsnot',
#   'sxsw'],
#  ['���',
#   'stupid',
#   'find',
#   'sxsw',
#   'mac',
#   'link',
#   'special',
#   'price',
#   'games',
#   'mac�\u06dd'],
#  ['slate',
#   'see',
#   'much',
#   'traffic',
#   'mobile',
#   'safari',
#   'app',
#   'ipad',
#   'sxsw',
#   'electricnews'],
#  ['unloading',
#   'apple',
#   'store',
#   'corner',
#   '6th',
#   'congress',
#   'austin',
#   'temp',
#   'store',
#   'sxsw',
#   'link'],
#  ['great',
#   'day',
#   'sxsw',
#   'jaloux',
#   'amp',
#   'new',
#   'ipadlook',
#   'school',
#   'bus',
#   '1st',
#   'day',
#   'school',
#   'link'],
#  ['arrived',
#   'sxsw',
#   'issue',
#   'hasnt',
#   'resolved',
#   'dying',
#   'use',
#   'iphone',
#   'app',
#   'cant',
#   'login',
#   'rt'],
#  ['sxsw',
#   'screenburn',
#   'launch',
#   'clients',
#   'new',
#   'iphone',
#   'game',
#   'travellerarlaunch',
#   'find',
#   'link'],
#  ['anyone', 'sxsw', 'wants', 'see', 'demo', 'piccraft', 'ipad', '2', 'find'],
#  ['sxsw',
#   'could',
#   'spend',
#   'teaching',
#   'theater',
#   'alone',
#   'look',
#   'schedule',
#   'link'],
#  ['youre',
#   'sxsw',
#   'meet',
#   'us',
#   'fado',
#   'give',
#   'wristbands',
#   'magically',
#   'lead',
#   'beer',
#   'come',
#   'say',
#   'hi',
#   'link'],
#  ['youre',
#   'sxsw',
#   'want',
#   'ipad',
#   '2',
#   'apples',
#   'setting',
#   'temporary',
#   'store',
#   'check',
#   'link'],
#  ['overheard',
#   'sxsw',
#   'quotthe',
#   'ipad',
#   'relaxing',
#   'computerquot',
#   'agreed',
#   'ipad',
#   'apple'],
#  ['overheard',
#   'sxsw',
#   'interactive',
#   'quotarg',
#   'hate',
#   'iphone',
#   'want',
#   'blackberry',
#   'backquot',
#   'shocked'],
#  ['youre',
#   'sxsw',
#   'meet',
#   'author',
#   'host',
#   'android',
#   'devs',
#   'sat',
#   '1230pm',
#   'hilton',
#   'room',
#   '615ab'],
#  ['���',
#   'sxsw',
#   'quotapple',
#   'comes',
#   'cool',
#   'technology',
#   'ones',
#   'ever',
#   'heard',
#   'dont',
#   'go',
#   'conferencesquot�\u06dd'],
#  ['sxsw',
#   'apple',
#   'sets',
#   '5000squarefoot',
#   'temporary',
#   'store',
#   'sxsw',
#   'sell',
#   'new',
#   'ipads',
#   'test',
#   'potential',
#   'traffic',
#   'link'],
#  ['overheard',
#   'sxsw',
#   'quotgoogle',
#   'doesnt',
#   'launch',
#   'products',
#   'peoples',
#   'eventsquot'],
#  ['nerd',
#   'bait',
#   'sxsw',
#   'apple',
#   'set',
#   'open',
#   'popup',
#   'shop',
#   'core',
#   'sxsw',
#   'action',
#   'link'],
#  ['long', 'line', 'sxsw', 'else', 'apple', 'store', 'link'],
#  ['last',
#   'year',
#   'sxswi',
#   'everbody',
#   'talking',
#   'ipad',
#   'year',
#   'social',
#   'media',
#   'driven',
#   'revolutions',
#   'year',
#   'good',
#   'sxsw'],
#  ['long',
#   'line',
#   'apple',
#   'pop',
#   'store',
#   'ipad',
#   '2',
#   'great',
#   'marketing',
#   'apple',
#   'sxsw'],
#  ['���',
#   'google',
#   '4',
#   'people',
#   'work',
#   '7',
#   'people',
#   'rather',
#   '7',
#   'people',
#   'work',
#   '4',
#   'agileagency',
#   'sxsw�\u06dd'],
#  ['knackered',
#   'home',
#   'playing',
#   'ipad',
#   'updating',
#   'iphone',
#   'timeline',
#   'smashed',
#   'partytweets',
#   'cant',
#   'make',
#   'go',
#   'bed',
#   'sxsw'],
#  ['overheard',
#   'mdw',
#   'ill',
#   'second',
#   'quothalfway',
#   'iphone',
#   'battery',
#   'already',
#   'havent',
#   'even',
#   'boarded',
#   'plane',
#   'sxswquot',
#   'amateurhour'],
#  ['technews',
#   'sxsw',
#   'apple',
#   'schools',
#   'marketing',
#   'experts',
#   'link',
#   'technews',
#   'apple',
#   'jobsco',
#   'sxsw',
#   'tech'],
#  ['first',
#   'day',
#   'sxsw',
#   'fun',
#   'final',
#   'presentation',
#   'google',
#   'doodles',
#   'googledoodle',
#   'sxsw'],
#  ['huge',
#   'line',
#   'apple',
#   'store',
#   'austin',
#   'sxsw',
#   'crowd',
#   'tripping',
#   'get',
#   'new',
#   'ipad'],
#  ['ur', 'google', 'aclu', '80s', 'partyu', 'sxsw'],
#  ['queue', 'apple', 'popup', 'store', 'sxsw', 'link'],
#  ['posted',
#   'dmi',
#   'house',
#   'intimate',
#   'strange',
#   'stage',
#   'got',
#   'restaurant',
#   'crowd',
#   'sitting',
#   'deal',
#   'wif',
#   'sxsw',
#   'link'],
#  ['woman',
#   'google',
#   'talk',
#   'sounded',
#   'like',
#   'chelsea',
#   'handler',
#   'lol',
#   'sxsw'],
#  ['laughed',
#   'ipad',
#   'spent',
#   'week',
#   'hauling',
#   'macbook',
#   'everywhere',
#   'really',
#   'want',
#   'ipad',
#   'shoulder',
#   'rub',
#   'sxsw'],
#  ['sxsw',
#   'attendees',
#   'need',
#   'qr',
#   'code',
#   'reader',
#   'iphone',
#   'tweet',
#   'us',
#   'image',
#   'badge',
#   'first',
#   '5',
#   'get',
#   'optiscan',
#   'free'],
#  ['hey',
#   'sxsw',
#   'attendeesyou',
#   'hop',
#   'line',
#   'apple',
#   'store',
#   'four',
#   'days',
#   'til',
#   'new',
#   'ipad2',
#   'comes'],
#  ['anyone',
#   'attending',
#   'google',
#   'amp',
#   'aclu',
#   'party',
#   'sxsw',
#   'could',
#   'plz',
#   'pictures',
#   'thanks',
#   'sxsw'],
#  ['march',
#   '11',
#   'austin',
#   'tx',
#   'people',
#   'line',
#   'sxsw',
#   'registration',
#   'apple',
#   'store'],
#  ['landed',
#   'austin',
#   'spotted',
#   'google',
#   'places',
#   'ads',
#   'sxsw',
#   'airport',
#   'quotthe',
#   'ultimate',
#   'austin',
#   'pocket',
#   'guidequot',
#   'like',
#   'yelp',
#   'itouru'],
#  ['took',
#   'away',
#   'lego',
#   'pit',
#   'replaced',
#   'recharging',
#   'station',
#   'sxsw',
#   'might',
#   'check',
#   'prices',
#   'iphone',
#   'crap',
#   'samsung',
#   'android'],
#  ['���',
#   'awesome',
#   'meet',
#   'standing',
#   'apple',
#   'queue',
#   'sxsw',
#   'yesterday',
#   'day',
#   '2�\u06ddltlt',
#   'cute'],
#  ['bad',
#   'apple',
#   'shows',
#   'late',
#   'qs',
#   'process',
#   'poopoos',
#   'ideas',
#   'leaves',
#   'early',
#   'even',
#   'quotim',
#   'creativequot',
#   'busy',
#   'gamestorming',
#   'sxsw'],
#  ['bahrain',
#   'govt',
#   'turned',
#   'google',
#   'earth',
#   'result',
#   'people',
#   'learned',
#   'govt',
#   'turn',
#   'back',
#   'sxsw'],
#  ['trying',
#   'balance',
#   'power',
#   'power',
#   'needs',
#   'iphone',
#   'vs',
#   'ipad',
#   'sxsw',
#   '3g',
#   'ipad',
#   'sucks',
#   'quick',
#   'might',
#   'go',
#   'airplane',
#   'mode'],
#  ['racing', 'ballroom', 'see', 'marissa', 'mayer', 'sxsw', 'sxswi'],
#  ['iphone', 'battery', '100', 'winning', 'sxsw'],
#  ['iphone',
#   'battery',
#   'cant',
#   'keep',
#   'tweets',
#   'thanks',
#   'apple',
#   'sxsw',
#   'precommerce'],
#  ['another',
#   'google',
#   'wave',
#   'rt',
#   'interrupt',
#   'regularly',
#   'scheduled',
#   'sxsw',
#   'geek',
#   'programming',
#   'wbig',
#   'google',
#   'news',
#   'link'],
#  ['fun',
#   'watch',
#   'ipadmadness',
#   'rt',
#   'apple',
#   'opening',
#   'popup',
#   'store',
#   'austin',
#   'sxsw',
#   'link',
#   'sxsw'],
#  ['control',
#   'apple',
#   'set',
#   'open',
#   'popup',
#   'shop',
#   'core',
#   'sxsw',
#   'action',
#   'link',
#   'via',
#   'cc'],
#  ['yeah', 'ill', 'sure', 'gtrt', 'check', 'link', 'sxsw', 'google'],
#  ['celebrate',
#   'beauty',
#   'web',
#   'msft',
#   'ie9',
#   'launch',
#   'amp',
#   'play',
#   'new',
#   'html5',
#   'game',
#   'win',
#   'ipad2',
#   'link',
#   'sxsw'],
#  ['texas',
#   'amazing',
#   'ive',
#   'met',
#   'many',
#   'influential',
#   'people',
#   'work',
#   'twitter',
#   'foursquare',
#   'microsoft',
#   'even',
#   'apple',
#   'sxsw',
#   'winning'],
#  ['woke',
#   'iphone',
#   'finished',
#   'recharging',
#   'means',
#   'got',
#   'enough',
#   'sleep',
#   'last',
#   'night',
#   'right',
#   'sxsw'],
#  ['quiet',
#   'storm',
#   'sxsw',
#   'looking',
#   'forward',
#   'seeing',
#   'googles',
#   'marissa',
#   'mayer'],
#  ['companies',
#   'believing',
#   'nfc',
#   'google',
#   'nexus',
#   'nokia',
#   'also',
#   'carriers',
#   'verifone',
#   'even',
#   'apple',
#   'seems',
#   'sxsw',
#   'sxswnfc'],
#  ['���',
#   'best',
#   'thing',
#   'ive',
#   'heard',
#   'weekend',
#   'sxsw',
#   'quoti',
#   'gave',
#   'ipad',
#   '2',
#   'money',
#   'japan',
#   'relief',
#   'dont',
#   'need',
#   'ipad',
#   '2quot'],
#  ['ipad', '2', 'betterthey', 'time', 'improve', 'sxsw'],
#  ['cus', 'pacman', 'google', 'singularity', 'sxsw', 'noobs', 'meetup'],
#  ['link',
#   'go',
#   'beyond',
#   'earth',
#   'hour',
#   'year',
#   'sharing',
#   'positive',
#   'actions',
#   'world',
#   'download',
#   'earthhour',
#   '60',
#   'iphone',
#   'app',
#   'sxsw'],
#  ['far', 'big', 'sxsw', 'mistake', 'bringing', 'iphoneipad', 'charger'],
#  ['google',
#   'vs',
#   'bing',
#   'bettersearch',
#   'bing',
#   'shot',
#   'success',
#   'w',
#   'structured',
#   'search',
#   'potentially',
#   'high',
#   'margin',
#   'cpa',
#   'model',
#   'vs',
#   'google',
#   'sxsw'],
#  ['course', 'bing', 'results', 'good', 'googles', 'seo', 'sxsw', 'qagb'],
#  ['���', 'black', 'white', 'ipad', 'sxsw', 'ipad2�\u06dd', 'question'],
#  ['hootsuite',
#   'blog',
#   '���',
#   'social',
#   'media',
#   'dashboard',
#   '��',
#   'hootsuite',
#   'mobile',
#   'sxsw',
#   'updates',
#   'iphone',
#   'blackberry',
#   'amp',
#   'android',
#   'link'],
#  ['hootsuite',
#   'blog',
#   '���',
#   'social',
#   'media',
#   'dashboard',
#   '��',
#   'hootsuite',
#   'mobile',
#   'sxsw',
#   'updates',
#   'iphone',
#   'blackberry',
#   'amp',
#   'android',
#   'link'],
#  ['hoot',
#   'new',
#   'blog',
#   'post',
#   'hootsuite',
#   'mobile',
#   'sxsw',
#   'updates',
#   'iphone',
#   'blackberry',
#   'amp',
#   'android',
#   'link'],
#  ['anyone', 'bringing', 'ipad', 'vs', 'computer', 'sxsw'],
#  ['impulsive',
#   'buy',
#   'friends',
#   'sxsw',
#   'gt',
#   'one',
#   'selling',
#   '1st',
#   'gen',
#   '32gb',
#   '3g',
#   'ipad'],
#  ['���',
#   'buying',
#   '2',
#   'new',
#   'ipads',
#   'geekdate',
#   'apple',
#   'sxsw',
#   'ipad2�\u06dd'],
#  ['someones',
#   'buying',
#   'present',
#   'rt',
#   'apple',
#   'opening',
#   'popup',
#   'store',
#   'austin',
#   'sxsw',
#   'link'],
#  ['nice', 'find', 'rsqs', 'link', 'sxsw', 'ipad', 'app'],
#  ['south',
#   'southwest',
#   'panels',
#   'illustrated',
#   'pics',
#   'sometimes',
#   'best',
#   'link',
#   'news',
#   'ogilvy',
#   'sxsw',
#   'trending',
#   'cyber',
#   'iphone'],
#  ['google',
#   'calendars',
#   'saturday',
#   'night',
#   'giant',
#   'overlap',
#   'sxsw',
#   'parties'],
#  ['quotyou', 'google', 'canadian', 'tuxedo', 'lose', 'hoursquot', 'sxsw'],
#  ['anyone',
#   'make',
#   'cool',
#   'rt',
#   'launch',
#   'quotgroupon',
#   'living',
#   'socialtypequot',
#   'rewards',
#   'sxsw',
#   'link'],
#  ['exciting',
#   'can�۪t',
#   'wait',
#   'rt',
#   'apple',
#   'opening',
#   'temporary',
#   'store',
#   'downtown',
#   'austin',
#   'sxsw',
#   'amp',
#   'ipad',
#   '2',
#   'launch',
#   'link'],
#  ['great',
#   'certain',
#   'meetings',
#   'rt',
#   'hello',
#   'holler',
#   'gram',
#   'new',
#   'ipad',
#   'app',
#   'link',
#   'hollergram',
#   'sxsw'],
#  ['dont',
#   'miss',
#   'charles',
#   'chen',
#   'androidchromeos',
#   'access',
#   'sxsw',
#   'google',
#   'booth',
#   'exhibit',
#   'hall',
#   '3',
#   '1pm',
#   'sxsw'],
#  ['reminder',
#   'charles',
#   'chen',
#   'talking',
#   'android',
#   'chromeos',
#   'access',
#   'today',
#   '1pm',
#   'google',
#   'booth',
#   'exhibit',
#   'hall',
#   '3',
#   'sxsw'],
#  ['tomorrow',
#   'charles',
#   'chen',
#   'speaking',
#   'android',
#   'chromeos',
#   'access',
#   'google',
#   'booth',
#   'exhibit',
#   'hall',
#   '3',
#   '1pm',
#   'sxsw'],
#  ['group',
#   'chat',
#   'apps',
#   'sxsw',
#   'told',
#   'dl',
#   'two',
#   'apps',
#   'yet',
#   'avail',
#   'android',
#   'point',
#   'ill',
#   'need',
#   'phone',
#   'apps'],
#  ['remember',
#   'chime',
#   'tweets',
#   'nasatweetup',
#   'experience',
#   '215pm',
#   '3pm',
#   'central',
#   'time',
#   'sxsw',
#   'session',
#   'link'],
#  ['daily',
#   'chord',
#   'tuesday',
#   'march',
#   '8',
#   'hackers',
#   'discover',
#   'googles',
#   'music',
#   'servicestory',
#   'rollin',
#   'link',
#   'sxsw',
#   'music',
#   'news'],
#  ['daily',
#   'chord',
#   'tuesday',
#   'march',
#   '8',
#   'hackers',
#   'discover',
#   'googles',
#   'music',
#   'servicestory',
#   'rolling',
#   'stone',
#   'mo',
#   'link',
#   'sxsw'],
#  ['google', 'circle', 'austin', 'sxsw', 'link'],
#  ['google',
#   'circles',
#   'sxsw',
#   'link',
#   'ht',
#   'maybe',
#   'theyre',
#   'reconsidering',
#   'shape'],
#  ['google',
#   'circles',
#   'buzz',
#   'corners',
#   'rounded',
#   'might',
#   'find',
#   'today',
#   'link',
#   'sxsw',
#   'google'],
#  ['google',
#   'circles',
#   'rt',
#   'launching',
#   'products',
#   'sxsw',
#   'plenty',
#   'else'],
#  ['10',
#   'austin',
#   'classics',
#   'missed',
#   'sxsw',
#   'm4blogcom',
#   'twitter',
#   'iphone',
#   '�ۢ',
#   '31211',
#   '1240',
#   'pm'],
#  ['tools',
#   'collaboration',
#   'across',
#   'boundaries',
#   'google',
#   'webex',
#   'dropbox',
#   'whiteboarding',
#   'basecamp',
#   'joinme',
#   'ipad',
#   'sxsw',
#   'evolvingworkplace'],
#  ['trying',
#   'collaborate',
#   'sxsw',
#   'events',
#   'friends',
#   'google',
#   'calendar',
#   'plancast'],
#  ['sxsw',
#   'come',
#   'hear',
#   'speak',
#   '40',
#   'mins',
#   'designing',
#   'ipad',
# ...
#   'today',
#   'link',
#   'sxsw'],
#  ['c34',
#   'it�۪s',
#   'retreat',
#   'link',
#   'codes',
#   'valid',
#   '120035959p',
#   '031411',
#   'infektd',
#   'sxsw',
#   'cvdc'],
#  ['���',
#   'rumor',
#   'apple',
#   'popup',
#   'store',
#   'downtown',
#   'austin',
#   'sxsw',
#   'amp',
#   'ipad',
#   '2',
#   'launch',
#   'link',
#   'smart',
#   'move',
#   '1of',
#   'many',
#   'dfcbto'],
#  ['anyone',
#   'hopping',
#   'groupon',
#   'bandwagon',
#   '���',
#   'launch',
#   'quotgroupon',
#   'living',
#   'socialtypequot',
#   'rewards',
#   'sxsw',
#   'link'],
#  ['google', 'launching', 'products', 'sxsw', 'link'],
#  ['google', 'launching', 'anything', 'sxsw', 'partying', 'link', 'circles'],
#  ['droid',
#   'surprised',
#   'rt',
#   'spotted',
#   'sxsw',
#   'table',
#   'three',
#   'people',
#   '8',
#   'phones',
#   'ipad',
#   'macbook',
#   'gadgetoverload'],
#  ['buy', 'buy', 'rt', 'even', 'begins', 'apple', 'wins��sxsw', 'link'],
#  ['farooqui',
#   'mobile',
#   'ios',
#   'android',
#   'catching',
#   'fast',
#   'grow',
#   'allow',
#   'inapp',
#   'purchasing',
#   'gamesfortv',
#   'sxsw'],
#  ['fear',
#   'extended',
#   'wed',
#   'gt',
#   'rt',
#   'rt',
#   'last',
#   'day',
#   'apple',
#   'popup',
#   'sunday',
#   '313',
#   'sxsw',
#   'appleatxdt'],
#  ['calvin', 'geek', 'charlie', 'sheen', 'goddesses', 'google', 'sxsw'],
#  ['quotwe',
#   'getting',
#   'feedback',
#   'sxsw',
#   'groups',
#   'amp',
#   'pushed',
#   'android',
#   'fix',
#   'grilled',
#   'cheese',
#   'stand',
#   'yesterdayquot'],
#  ['manufacturing',
#   'serendipity',
#   'quothaving',
#   'access',
#   'information',
#   'makes',
#   'us',
#   'curious',
#   'lessquot',
#   'sxsw'],
#  ['quotall',
#   'sxsw',
#   'nothing',
#   'teeming',
#   'sea',
#   'iphone',
#   'addicts',
#   'busy',
#   'twittering',
#   'ever',
#   'engage',
#   'one',
#   'anoth��',
#   'cont',
#   'link'],
#  ['fan',
#   'new',
#   'sxsw',
#   'trend',
#   'audience',
#   'sharing',
#   'opinions',
#   'via',
#   'holding',
#   'ipad',
#   'listen',
#   'annoying'],
#  ['quot40',
#   'google',
#   'maps',
#   'usage',
#   'mobilequot',
#   'marissa',
#   'mayer',
#   'sxsw'],
#  ['power',
#   'apple',
#   'people',
#   'spent',
#   'hundreds',
#   'dollars',
#   'attend',
#   'sxsw',
#   'spending',
#   'day',
#   'waiting',
#   'line',
#   'ipad'],
#  ['continuum',
#   'attitudes',
#   'crowdsourcing',
#   'gap',
#   'quoti',
#   'hear',
#   'youquot',
#   'apple',
#   'quotill',
#   'tell',
#   'youquot',
#   'sxsw'],
#  ['google',
#   'vp',
#   'consumer',
#   'products',
#   'marissa',
#   'mayer',
#   'says',
#   'location',
#   'everything',
#   'link',
#   'sxsw'],
#  ['third',
#   'era',
#   'google',
#   'logos',
#   'interactive',
#   'play',
#   'space',
#   'get',
#   'ready',
#   'googledoodle',
#   'sxsw',
#   'gsdm'],
#  ['new',
#   'batch',
#   'ipad',
#   '2s',
#   'delivered',
#   'sxsw',
#   'ipad2',
#   'apple',
#   'store',
#   'sxsw',
#   'link',
#   'photo'],
#  ['highlight',
#   'day',
#   'undoubtedly',
#   'meeting',
#   'google',
#   '30',
#   'seconds',
#   'softball',
#   'fancrazed',
#   'preso',
#   'sxsw'],
#  ['cool',
#   'team',
#   'startups',
#   'came',
#   'via',
#   'siliconvalley',
#   'bus',
#   'hacking',
#   'apps',
#   'exgoogle',
#   'au',
#   'stage',
#   'w',
#   'speakermeetup',
#   'sxsw',
#   'dogpatch',
#   'labs'],
#  ['wow',
#   'lots',
#   'sxsw',
#   'audience',
#   'havent',
#   'seen',
#   '3d',
#   'vector',
#   'panning',
#   'google',
#   'maps',
#   'mobile',
#   'gasps',
#   'appreciation'],
#  ['first', 'leg', 'mobile', 'social', 'sxsw', 'fb', 'link'],
#  ['i14',
#   'call',
#   'zombie',
#   'link',
#   'codes',
#   'valid',
#   '40075959p',
#   '031211',
#   'infektd',
#   'sxsw',
#   'zomb'],
#  ['i18',
#   'call',
#   'zombie',
#   'link',
#   'codes',
#   'valid',
#   '800115959p',
#   '031211',
#   'infektd',
#   'sxsw',
#   'zomb'],
#  ['tomlinson',
#   'tx',
#   'observer',
#   'says',
#   'apple',
#   'subscription',
#   'data',
#   'holding',
#   'big',
#   'impediment',
#   'success',
#   'newsapps',
#   'sxsw'],
#  ['tip',
#   'turn',
#   'push',
#   'amp',
#   'set',
#   'fetch',
#   'manual',
#   'mode',
#   'email',
#   'mailcontacts',
#   'amp',
#   'cal',
#   'gt',
#   'fetch',
#   'new',
#   'data',
#   'saves',
#   'battery',
#   'iphone',
#   'sxsw'],
#  ['���',
#   'official',
#   'sxsw',
#   'app',
#   '���sxsw',
#   'go�۪',
#   'link',
#   'android',
#   'iphone',
#   'ipad�\u06dd',
#   'ltthanksinstalled'],
#  ['zazzle',
#   'officially',
#   'sxsw',
#   'come',
#   'grille',
#   'mention',
#   'us',
#   'zazzlsxsw',
#   'you�۪ll',
#   'get',
#   'make',
#   'iphone',
#   'case'],
#  ['technews',
#   'omgjk',
#   'kiss',
#   'ipad',
#   '2',
#   'slap',
#   'xoom',
#   'link',
#   'technews',
#   'ipad2',
#   'jk',
#   'omg',
#   'sxsw',
#   'tech'],
#  ['sxsw', 'cr48', 'theres', 'much', 'potential', 'link'],
#  ['idle',
#   'time',
#   'sxsw',
#   'friday',
#   'expensive',
#   'thing',
#   'apple',
#   'store',
#   'sxsw',
#   'w',
#   '80',
#   'others',
#   'pic',
#   'link'],
#  ['also',
#   'android',
#   'rt',
#   'foodspottings',
#   'hit',
#   'iphone',
#   'app',
#   'finds',
#   'foods',
#   'crave',
#   'link',
#   'cnnmoneysxsw',
#   'sxsw'],
#  ['usa',
#   'today',
#   'ipad',
#   'makes',
#   'good',
#   'use',
#   'digital',
#   'shortcuts',
#   'still',
#   'looking',
#   'like',
#   'newspaper',
#   'tapworthy',
#   'sxsw'],
#  ['iphone',
#   'one',
#   'hand',
#   'caramel',
#   'macchiato',
#   'ouchhisshot',
#   'apparently',
#   'two',
#   'pumps',
#   'lava',
#   'begins',
#   'sxsw',
#   'tmsxsw'],
#  ['thats',
#   'one',
#   'want',
#   'get',
#   'hits',
#   'canadart',
#   'sxsw',
#   'ipad',
#   'store',
#   'sold',
#   'everything',
#   'except',
#   '64gig',
#   'wifi',
#   'white'],
#  ['one',
#   'million',
#   'ratings',
#   'per',
#   'month',
#   'google',
#   'hotpot',
#   'sxsw',
#   'pr'],
#  ['haz',
#   'one',
#   '���',
#   'showed',
#   'charge',
#   'anywhere',
#   'bar',
#   'charge',
#   'iphone',
#   'whole',
#   'table',
#   'wanted',
#   'buy',
#   'one',
#   'sxsw�\u06dd'],
#  ['quotthe',
#   'explanation',
#   'continued',
#   'success',
#   'apple',
#   'existence',
#   'godquot',
#   'enchantment',
#   'sxsw'],
#  ['apple',
#   'open',
#   'quotpopupquot',
#   'store',
#   'across',
#   'street',
#   'sxsw',
#   'two',
#   'weeks',
#   'umm',
#   'genius',
#   'isnt',
#   'obvious',
#   'cough',
#   'ipad2',
#   'cough'],
#  ['open',
#   'time',
#   'tues',
#   'amp',
#   'wed',
#   'news',
#   'site',
#   'managers',
#   'want',
#   'chat',
#   'google',
#   'news',
#   'let',
#   'know',
#   'sxsw'],
#  ['wear',
#   'openbeta',
#   'vip',
#   'badge',
#   'sxsw',
#   'might',
#   'win',
#   'ipad',
#   'quibids',
#   'case',
#   'sxswbuffalo'],
#  ['apple',
#   'opened',
#   'makeshift',
#   'store',
#   'sxsw',
#   'ipad2',
#   'available',
#   '5pm',
#   'today',
#   'tempted'],
#  ['launching',
#   'iphone',
#   'app',
#   'soon',
#   'participating',
#   'launchrock',
#   'comp',
#   'sxsw',
#   'link',
#   'get',
#   'invite'],
#  ['hey',
#   'sxsw',
#   'new',
#   'ipad',
#   'app',
#   'dexteria',
#   'available',
#   'link',
#   'like',
#   'us',
#   'facebook',
#   'link'],
#  ['ipad',
#   '2',
#   'plenty',
#   'people',
#   'storeand',
#   'linescarfing',
#   'sxsw',
#   'apple',
#   'store',
#   'sxsw',
#   'w',
#   '65',
#   'others',
#   'link'],
#  ['nice',
#   'line',
#   'outside',
#   'sxsw',
#   'apple',
#   'store',
#   'guess',
#   'people',
#   'want',
#   'ipad2s'],
#  ['confusion',
#   'google',
#   'circles',
#   'google',
#   'claim',
#   'circles',
#   'released',
#   'sxsw',
#   'even',
#   'development',
#   'link'],
#  ['packing', 'point', 'showing', 'iphone', 'fragmentation', 'sxsw'],
#  ['attending',
#   'panel',
#   'quotbetter',
#   'living',
#   'cloud',
#   'computing',
#   'quot',
#   'presented',
#   'googles',
#   'jon',
#   'wiley',
#   'sxsw'],
#  ['one',
#   'sxsw',
#   'panel',
#   'moderator',
#   'europe',
#   'says',
#   'spent',
#   '3000',
#   'roaming',
#   'charges',
#   'iphone',
#   'sxsw',
#   '2010'],
#  ['brown',
#   'paper',
#   'windows',
#   'line',
#   'grows',
#   'sxsw',
#   'popup',
#   'apple',
#   'store',
#   'golds',
#   'gym',
#   'sixth',
#   'amp',
#   'congress',
#   'link'],
#  ['sxsw',
#   'two',
#   'parties',
#   'awesome',
#   'journalism',
#   'nprgoogle',
#   'one',
#   'go',
#   'pbs'],
#  ['google', 'party', 'best', 'ever', 'get', 'butt', 'sxsw'],
#  ['hey',
#   'sxsw',
#   'peeps',
#   'new',
#   'iphone',
#   'app',
#   'voicefeed',
#   'launched',
#   'us',
#   'link',
#   'check',
#   'let',
#   'us',
#   'know',
#   'think'],
#  ['watch',
#   'people',
#   'interact',
#   'information',
#   'different',
#   'big',
#   'small',
#   'touchingstories',
#   'ipad',
#   'andor',
#   'tablet',
#   'sxsw'],
#  ['hey',
#   'sxsw',
#   'people',
#   'survival',
#   'tip',
#   '2',
#   'great',
#   'vegitarianvegan',
#   'right',
#   'think',
#   'action',
#   'mr',
#   'natural',
#   'link',
#   'sxswsurvival'],
#  ['sxsw',
#   'pepsi',
#   'max',
#   'marketing',
#   'street',
#   'team',
#   'shown',
#   'popup',
#   'apple',
#   'store',
#   'line',
#   'handing',
#   'drinks',
#   'amp',
#   'tshirts',
#   'link'],
#  ['new',
#   'post',
#   'per',
#   'rumor',
#   'google',
#   'may',
#   'preview',
#   'big',
#   'social',
#   'strategy',
#   '80sthemed',
#   'costume',
#   'party',
#   'sxsw',
#   'yep',
#   'link'],
#  ['instagram',
#   'photo',
#   'iamtimbaker',
#   'googles',
#   '1980s',
#   'sxsw',
#   'party',
#   'link'],
#  ['trying',
#   'pick',
#   'theme',
#   'sxsw',
#   'year',
#   'think',
#   'may',
#   'opening',
#   'data',
#   'google',
#   'government',
#   'sxsw',
#   'bolinsxsw'],
#  ['google',
#   'planning',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'previews',
#   'far',
#   'super',
#   'positive',
#   'sxsw',
#   'link'],
#  ['mashable',
#   'platform',
#   'concertgoers',
#   'launches',
#   'android',
#   'app',
#   'time',
#   'sxsw',
#   'link',
#   'sxsw',
#   'link'],
#  ['game', 'play', 'swsx', 'spot', 'non', 'apple', 'electronics', 'sxsw'],
#  ['need', 'play', 'game', 'android', 'sxsw', 'link'],
#  ['grown',
#   'men',
#   'playing',
#   'legos',
#   'google',
#   'party',
#   'sxsw',
#   'speakeasy',
#   'link'],
#  ['left',
#   'pocket',
#   'guide',
#   'hotel',
#   'dont',
#   'know',
#   'im',
#   'going',
#   'cope',
#   'say',
#   'usability',
#   'ipadiphone',
#   'app',
#   'sxsw'],
#  ['check',
#   'poked',
#   'liked',
#   'amp',
#   'retweeted',
#   'google',
#   'love',
#   'story',
#   'sxsw',
#   'link',
#   'sxsw',
#   'sxsw15',
#   'sxswic'],
#  ['check',
#   'poked',
#   'liked',
#   'amp',
#   'retweeted',
#   'google',
#   'love',
#   'story',
#   'sxsw',
#   'sxsw',
#   'sxsw15',
#   'sxswic'],
#  ['temporary', 'pop', 'shop', 'apple', 'sxsw', 'nice', 'flipboard', 'upgrade'],
#  ['apple', 'pop', 'store', 'sxsw', 'joke'],
#  ['found', 'popup', 'apple', 'store', 'sxsw'],
#  ['apple',
#   'popup',
#   'store',
#   'attractive',
#   'impressive',
#   'many',
#   'permanent',
#   'retail',
#   'stores',
#   'sxsw'],
#  ['apple',
#   'popup',
#   'store',
#   'line',
#   'finally',
#   'dwindled',
#   'time',
#   'check',
#   'ipad2',
#   'sxsw'],
#  ['apple',
#   'popup',
#   'store',
#   'hook',
#   'last',
#   'night',
#   'sxsw',
#   'singing',
#   'dancing',
#   'high',
#   'fives',
#   'new',
#   'ipad',
#   'purchase'],
#  ['wordpress',
#   'powers',
#   '12',
#   'websites',
#   'sxsw',
#   'talk',
#   'wp',
#   'founder',
#   'wow',
#   '88',
#   'russian',
#   'spam',
#   'bots',
#   'nigerian',
#   'bankers',
#   'google'],
#  ['brilliant',
#   'pr',
#   'stunt',
#   'business',
#   'idea',
#   'customer',
#   'service',
#   'response',
#   'one',
#   'apple',
#   'sets',
#   'popup',
#   'store',
#   'sxsw',
#   'draws',
#   'crowds',
#   'media',
#   'amp',
#   'revenue'],
#  ['panels',
#   'pr',
#   'cloud',
#   'computing',
#   'android',
#   'design',
#   'iphone',
#   'design',
#   'today',
#   'hope',
#   'redeem',
#   'panel',
#   'experience',
#   'one',
#   'fell',
#   'swoop',
#   'sxsw'],
#  ['excellent',
#   'presentation',
#   'quotthe',
#   'untapped',
#   'ipad',
#   'market',
#   'site',
#   'pourquot',
#   'sxsw',
#   'poursite',
#   'accessibility'],
#  ['excellent',
#   'presentation',
#   'digital',
#   'magazines',
#   'link',
#   'touchingstories',
#   'sxsw'],
#  ['hey',
#   'sxsw',
#   'presenters',
#   'amp',
#   'attendees',
#   'tips',
#   'show',
#   'presentations',
#   'ipad',
#   'iphone',
#   'link'],
#  ['ipad',
#   '2',
#   'pretty',
#   'sick',
#   'almost',
#   'makes',
#   'think',
#   'need',
#   'one',
#   'sxsw'],
#  ['google',
#   'preview',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'sxsw',
#   'interactive',
#   'today',
#   'link',
#   'google',
#   'social',
#   'sxsw',
#   'circles'],
#  ['google',
#   'preview',
#   'social',
#   'networking',
#   'platform',
#   'sxsw',
#   'conference',
#   'link'],
#  ['problem',
#   'google',
#   'living',
#   'stories',
#   'process',
#   'creating',
#   'content',
#   'didnt',
#   'change',
#   'interface',
#   'hacknews',
#   'sxsw'],
#  ['���',
#   'problems��time',
#   'stop',
#   '��',
#   'link',
#   '��',
#   'edchat',
#   'musedchat',
#   'sxsw',
#   'sxswi',
#   'classical',
#   'newtwitter'],
#  ['im', 'q', 'apple', 'pop', 'store', 'sxsw', 'link'],
#  ['check',
#   'qampa',
#   'google',
#   'amp',
#   'bing',
#   'website',
#   'ranking',
#   'sxsw',
#   'link',
#   'sxsw',
#   'qagb'],
#  ['check',
#   'qampa',
#   'google',
#   'amp',
#   'bing',
#   'website',
#   'ranking',
#   'sxsw',
#   'sxsw',
#   'qagb',
#   'sxsma'],
#  ['���',
#   'qik',
#   'video',
#   'connect',
#   'plus',
#   'launches',
#   'today',
#   'get',
#   'live',
#   'video',
#   'chat',
#   'video',
#   'mail',
#   'share',
#   'live',
#   'video',
#   'twitter',
#   'sxsw�\u06dd',
#   'make',
#   'ipad'],
#  ['ne',
#   'sapete',
#   'qualcosa',
#   '���',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'possibly',
#   'today',
#   'link',
#   'sxsw�\u06dd'],
#  ['youre',
#   'racing',
#   'around',
#   'sxsw',
#   'best',
#   'fueling',
#   'great',
#   'local',
#   'fare',
#   'eatshopaustinapp',
#   'link'],
#  ['radar',
#   'google',
#   'circus',
#   'rt',
#   'google',
#   'launch',
#   'new',
#   'social',
#   'network',
#   'circles',
#   'via',
#   'link',
#   'pr',
#   'sxsw'],
#  ['brilliant',
#   'read',
#   'attention',
#   'marketers',
#   'media',
#   'professionals',
#   'ipad',
#   'wont',
#   'save',
#   'link',
#   'usguys',
#   'sxsw'],
#  ['augmented',
#   'reality',
#   'pah',
#   'mayer',
#   'google',
#   'calls',
#   'quotcontextual',
#   'discoveryquot',
#   '���',
#   'searches',
#   'without',
#   'search',
#   'users',
#   'permission',
#   'sxsw'],
#  ['rec',
#   'give',
#   'bad',
#   'apple',
#   'job',
#   'mtg',
#   'taking',
#   'notes',
#   'make',
#   'mtg',
#   'voluntary',
#   'gt',
#   'willing',
#   'participants',
#   'gamestorming',
#   'sxsw'],
#  ['google',
#   'reproducing',
#   'digitally',
#   'way',
#   'organically',
#   'consume',
#   'information',
#   'goggles',
#   'best',
#   'example',
#   'sxsw',
#   'marissameyer'],
#  ['future',
#   'retail',
#   'instore',
#   'party',
#   'goods',
#   'front',
#   'biz',
#   'inventory',
#   'back',
#   'ala',
#   'apple',
#   'mullet',
#   'sxsw',
#   'kiosks'],
#  ['retiring',
#   'wine',
#   'library',
#   'tv',
#   'moving',
#   'onto',
#   'daily',
#   'grape',
#   'get',
#   'app',
#   'yr',
#   'iphone',
#   'thankyouecon',
#   'sxsw'],
#  ['reveals',
#   'average',
#   'time',
#   'users',
#   'spent',
#   'nyts',
#   'oscars',
#   'ipad',
#   'app',
#   '16mins',
#   'quotthat',
#   'blew',
#   'mindquot',
#   'newsapps',
#   'sxsw'],
#  ['right', '3', 'app', 'android', 'sweeeeet', 'nice', 'job', 'team', 'sxsw'],
#  ['���',
#   'rt',
#   'marissa',
#   'mayer',
#   'google',
#   'connect',
#   'digital',
#   'amp',
#   'physical',
#   'worlds',
#   'mobile',
#   'link',
#   'sxsw�\u06dd'],
#  ['���',
#   'rt',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'possibly',
#   'today',
#   'link',
#   'sxsw�\u06dd'],
#  ['���',
#   'rt',
#   'google',
#   'launch',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'possibly',
#   'today',
#   'link',
#   'sxsw�\u06dd',
#   'reported',
#   'buzz'],
#  ['���',
#   'rt',
#   'interrupt',
#   'regularly',
#   'scheduled',
#   'sxsw',
#   'geek',
#   'programming',
#   'big',
#   'news',
#   'link',
#   'google',
#   'circles�\u06dd'],
#  ['rt',
#   'apple',
#   'store',
#   'downtown',
#   'austin',
#   'open',
#   'til',
#   'midnight',
#   'sxsw'],
#  ['rt',
#   'mayer',
#   '20',
#   'google',
#   'searches',
#   'local',
#   'information',
#   'sxsw',
#   'pr'],
#  ['bsocial',
#   'rt',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'possibly',
#   'today',
#   'link',
#   'sxsw'],
#  ['congrats',
#   'rt',
#   'good',
#   'news',
#   'austin',
#   'eats',
#   'bbq',
#   'iphone',
#   'available',
#   'link',
#   'itunes',
#   'austin',
#   'bbq',
#   'sxsw',
#   'sxswi'],
#  ['congrats',
#   'rt',
#   'awesome',
#   'ipad',
#   'sxswbuffalo',
#   'lounge',
#   'sxsw',
#   'experience',
#   'complete',
#   'quibidswin'],
#  ['congrats',
#   'rt',
#   'yes',
#   'gowalla',
#   'wins',
#   'best',
#   'andoid',
#   'app',
#   'team',
#   'android',
#   'choice',
#   'awards',
#   'thanks',
#   'sxsw'],
#  ['eh',
#   'rt',
#   'google',
#   'launch',
#   'major',
#   'new',
#   'social',
#   'network',
#   'called',
#   'circles',
#   'possibly',
#   'today',
#   'link',
#   'sxsw'],
#  ['like',
#   'rt',
#   'quotgoogle',
#   'tweetquot',
#   'new',
#   'quotthink',
#   'speakquot',
#   'mark',
#   'belinsky',
#   '911tweets',
#   'panel',
#   'sxsw'],
#  ['lame',
#   'rt',
#   'quotby',
#   'law',
#   'averages',
#   'good',
#   'buzzquot',
#   'rt',
#   'quotgoogle',
#   'circles',
#   'quot',
#   'sxsw'],
#  ['love',
#   'rt',
#   'apple',
#   'naomi',
#   'campbell',
#   'popup',
#   'stores',
#   'rage',
#   'link',
#   'sxsw'],
#  ...]

# %%
import gensim

# %%
model = gensim.models.Word2Vec(sentences=review_lines, size=EMBEDDING_DIM, window=5, workers=4, min_count=1)

# %%
words = list(model.wv.vocab)

# %%
print('Vocabulary Size: %d' % len(words))
# Out:
# Vocabulary Size: 10380

# %%
model.wv.most_similar('help')
# Out:
# [('room', 0.9999278783798218),
#  ('meet', 0.9998672008514404),
#  ('without', 0.9998671412467957),
#  ('say', 0.9998602271080017),
#  ('user', 0.9998586773872375),
#  ('much', 0.9998446106910706),
#  ('also', 0.9998436570167542),
#  ('hit', 0.9998413324356079),
#  ('give', 0.9998410940170288),
#  ('battery', 0.9998387098312378)]

# %%
filename = 'twitter_embedding_word2vec.txt'
model.wv.save_word2vec_format(filename, binary=False)

# %%
len(review_lines)
# Out:
# 8547

# %%
import os

embeddings_index = {}
f = open(os.path.join('', 'twitter_embedding_word2vec.txt'),  encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:])
    embeddings_index[word] = coefs
f.close()

# %%
VALIDATION_SPLIT = 0.3

# vectorize the text samples into a 2D integer tensor
tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(review_lines)
sequences = tokenizer_obj.texts_to_sequences(review_lines)

# pad sequences
word_index = tokenizer_obj.word_index
print('Found %s unique tokens.' % len(word_index))

review_pad = pad_sequences(sequences, maxlen=max_length)
sentiment =  df['sentiment'].values
print('Shape of review tensor:', review_pad.shape)
print('Shape of sentiment tensor:', sentiment.shape)

# split the data into a training set and a validation set
indices = np.arange(review_pad.shape[0])
np.random.shuffle(indices)
review_pad = review_pad[indices]
sentiment = sentiment[indices]
num_validation_samples = int(VALIDATION_SPLIT * review_pad.shape[0])

X_train_pad = review_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
X_test_pad = review_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]
# Out:
# Found 10380 unique tokens.
# Shape of review tensor: (8547, 26)
# Shape of sentiment tensor: (8547,)

# %%
print('Shape of X_train_pad tensor:', X_train_pad.shape)
print('Shape of y_train tensor:', y_train.shape)

print('Shape of X_test_pad tensor:', X_test_pad.shape)
print('Shape of y_test tensor:', y_test.shape)
# Out:
# Shape of X_train_pad tensor: (5983, 26)
# Shape of y_train tensor: (5983,)
# Shape of X_test_pad tensor: (2564, 26)
# Shape of y_test tensor: (2564,)

# %%
EMBEDDING_DIM =100
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))

for word, i in word_index.items():
    if i > num_words:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
print(num_words)
# Out:
# 10381

# %%
lb = LabelBinarizer()
lb.fit(y_train)

y_train_lb = to_categorical(lb.transform(y_train))[:, :, 1]
y_test_lb = to_categorical(lb.transform(y_test))[:, :, 1]

# %%
from keras.models import Sequential
from keras.layers import Dense, Embedding, Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.initializers import Constant

# define model
model = Sequential()
# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=max_length,
                            trainable=False)

model.add(embedding_layer)
model.add(Conv1D(filters=128, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(3, activation='softmax'))
print(model.summary())

# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit the model
model.fit(X_train_pad, y_train_lb, batch_size=128, epochs=50, validation_data=(X_test_pad, y_test_lb), verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 26, 100)           1038100
# _________________________________________________________________
# conv1d (Conv1D)              (None, 22, 128)           64128
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 11, 128)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 1408)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 4227
# =================================================================
# Total params: 1,106,455
# Trainable params: 68,355
# Non-trainable params: 1,038,100
# _________________________________________________________________
# None
# Epoch 1/50
# 47/47 - 1s - loss: 0.5320 - accuracy: 0.5771 - val_loss: 0.5232 - val_accuracy: 0.5846
# Epoch 2/50
# 47/47 - 1s - loss: 0.5048 - accuracy: 0.6045 - val_loss: 0.5090 - val_accuracy: 0.5870
# Epoch 3/50
# 47/47 - 1s - loss: 0.5037 - accuracy: 0.6022 - val_loss: 0.5054 - val_accuracy: 0.5870
# Epoch 4/50
# 47/47 - 1s - loss: 0.4984 - accuracy: 0.6087 - val_loss: 0.5043 - val_accuracy: 0.5952
# Epoch 5/50
# 47/47 - 1s - loss: 0.4963 - accuracy: 0.6109 - val_loss: 0.5056 - val_accuracy: 0.5932
# Epoch 6/50
# 47/47 - 1s - loss: 0.4914 - accuracy: 0.6142 - val_loss: 0.5101 - val_accuracy: 0.5909
# Epoch 7/50
# 47/47 - 1s - loss: 0.4881 - accuracy: 0.6219 - val_loss: 0.5033 - val_accuracy: 0.5893
# Epoch 8/50
# 47/47 - 1s - loss: 0.4859 - accuracy: 0.6169 - val_loss: 0.5019 - val_accuracy: 0.5846
# Epoch 9/50
# 47/47 - 1s - loss: 0.4816 - accuracy: 0.6219 - val_loss: 0.5139 - val_accuracy: 0.5854
# Epoch 10/50
# 47/47 - 2s - loss: 0.4791 - accuracy: 0.6239 - val_loss: 0.5076 - val_accuracy: 0.5768
# Epoch 11/50
# 47/47 - 2s - loss: 0.4797 - accuracy: 0.6261 - val_loss: 0.5053 - val_accuracy: 0.5850
# Epoch 12/50
# 47/47 - 2s - loss: 0.4739 - accuracy: 0.6326 - val_loss: 0.5118 - val_accuracy: 0.5842
# Epoch 13/50
# 47/47 - 1s - loss: 0.4710 - accuracy: 0.6333 - val_loss: 0.5116 - val_accuracy: 0.5874
# Epoch 14/50
# 47/47 - 1s - loss: 0.4702 - accuracy: 0.6360 - val_loss: 0.5091 - val_accuracy: 0.5835
# Epoch 15/50
# 47/47 - 2s - loss: 0.4648 - accuracy: 0.6453 - val_loss: 0.5140 - val_accuracy: 0.5905
# Epoch 16/50
# 47/47 - 2s - loss: 0.4632 - accuracy: 0.6433 - val_loss: 0.5179 - val_accuracy: 0.5924
# Epoch 17/50
# 47/47 - 1s - loss: 0.4596 - accuracy: 0.6487 - val_loss: 0.5131 - val_accuracy: 0.5846
# Epoch 18/50
# 47/47 - 1s - loss: 0.4545 - accuracy: 0.6545 - val_loss: 0.5139 - val_accuracy: 0.5866
# Epoch 19/50
# 47/47 - 1s - loss: 0.4540 - accuracy: 0.6572 - val_loss: 0.5160 - val_accuracy: 0.5936
# Epoch 20/50
# 47/47 - 1s - loss: 0.4501 - accuracy: 0.6587 - val_loss: 0.5213 - val_accuracy: 0.5866
# Epoch 21/50
# 47/47 - 2s - loss: 0.4464 - accuracy: 0.6676 - val_loss: 0.5185 - val_accuracy: 0.5881
# Epoch 22/50
# 47/47 - 1s - loss: 0.4475 - accuracy: 0.6577 - val_loss: 0.5177 - val_accuracy: 0.5788
# Epoch 23/50
# 47/47 - 1s - loss: 0.4439 - accuracy: 0.6694 - val_loss: 0.5240 - val_accuracy: 0.5807
# Epoch 24/50
# 47/47 - 1s - loss: 0.4410 - accuracy: 0.6686 - val_loss: 0.5347 - val_accuracy: 0.5917
# Epoch 25/50
# 47/47 - 2s - loss: 0.4364 - accuracy: 0.6737 - val_loss: 0.5282 - val_accuracy: 0.5757
# Epoch 26/50
# 47/47 - 2s - loss: 0.4351 - accuracy: 0.6736 - val_loss: 0.5230 - val_accuracy: 0.5862
# Epoch 27/50
# 47/47 - 1s - loss: 0.4309 - accuracy: 0.6844 - val_loss: 0.5293 - val_accuracy: 0.5823
# Epoch 28/50
# 47/47 - 2s - loss: 0.4300 - accuracy: 0.6794 - val_loss: 0.5295 - val_accuracy: 0.5920
# Epoch 29/50
# 47/47 - 1s - loss: 0.4245 - accuracy: 0.6931 - val_loss: 0.5439 - val_accuracy: 0.5897
# Epoch 30/50
# 47/47 - 2s - loss: 0.4244 - accuracy: 0.6839 - val_loss: 0.5316 - val_accuracy: 0.5913
# Epoch 31/50
# 47/47 - 2s - loss: 0.4196 - accuracy: 0.6928 - val_loss: 0.5368 - val_accuracy: 0.5881
# Epoch 32/50
# 47/47 - 2s - loss: 0.4173 - accuracy: 0.6971 - val_loss: 0.5373 - val_accuracy: 0.5831
# Epoch 33/50
# 47/47 - 2s - loss: 0.4161 - accuracy: 0.6943 - val_loss: 0.5370 - val_accuracy: 0.5636
# Epoch 34/50
# 47/47 - 2s - loss: 0.4195 - accuracy: 0.6905 - val_loss: 0.5384 - val_accuracy: 0.5831
# Epoch 35/50
# 47/47 - 1s - loss: 0.4099 - accuracy: 0.7070 - val_loss: 0.5406 - val_accuracy: 0.5971
# Epoch 36/50
# 47/47 - 1s - loss: 0.4104 - accuracy: 0.6998 - val_loss: 0.5396 - val_accuracy: 0.5901
# Epoch 37/50
# 47/47 - 2s - loss: 0.4056 - accuracy: 0.7013 - val_loss: 0.5513 - val_accuracy: 0.6030
# Epoch 38/50
# 47/47 - 1s - loss: 0.4051 - accuracy: 0.7103 - val_loss: 0.5471 - val_accuracy: 0.5967
# Epoch 39/50
# 47/47 - 2s - loss: 0.4000 - accuracy: 0.7100 - val_loss: 0.5596 - val_accuracy: 0.5936
# Epoch 40/50
# 47/47 - 2s - loss: 0.4006 - accuracy: 0.7127 - val_loss: 0.5539 - val_accuracy: 0.5885
# Epoch 41/50
# 47/47 - 1s - loss: 0.3961 - accuracy: 0.7165 - val_loss: 0.5503 - val_accuracy: 0.5842
# Epoch 42/50
# 47/47 - 2s - loss: 0.3953 - accuracy: 0.7170 - val_loss: 0.5676 - val_accuracy: 0.5897
# Epoch 43/50
# 47/47 - 2s - loss: 0.3959 - accuracy: 0.7145 - val_loss: 0.5583 - val_accuracy: 0.5893
# Epoch 44/50
# 47/47 - 2s - loss: 0.3899 - accuracy: 0.7212 - val_loss: 0.5595 - val_accuracy: 0.5722
# Epoch 45/50
# 47/47 - 2s - loss: 0.3903 - accuracy: 0.7189 - val_loss: 0.5629 - val_accuracy: 0.5897
# Epoch 46/50
# 47/47 - 2s - loss: 0.3876 - accuracy: 0.7215 - val_loss: 0.5716 - val_accuracy: 0.5558
# Epoch 47/50
# 47/47 - 1s - loss: 0.3919 - accuracy: 0.7177 - val_loss: 0.5670 - val_accuracy: 0.5776
# Epoch 48/50
# 47/47 - 1s - loss: 0.3870 - accuracy: 0.7269 - val_loss: 0.5701 - val_accuracy: 0.5800
# Epoch 49/50
# 47/47 - 1s - loss: 0.3805 - accuracy: 0.7321 - val_loss: 0.5759 - val_accuracy: 0.5995
# Epoch 50/50
# 47/47 - 1s - loss: 0.3783 - accuracy: 0.7337 - val_loss: 0.5659 - val_accuracy: 0.5831
